# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv
import os
from pprint import pprint as pp

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_directory = 'output_data'
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %%
pp(cities)
# Out:
# ['turayf',
#  'bengkulu',
#  'tupik',
#  'kavieng',
#  'north bend',
#  'youghal',
#  'vao',
#  'katsuura',
#  'hobyo',
#  'punta arenas',
#  'butaritari',
#  'atuona',
#  'abha',
#  'poum',
#  'kenai',
#  'farrukhnagar',
#  'clearlake',
#  'buenos aires',
#  'rikitea',
#  'vaini',
#  'santa lucia',
#  'emborion',
#  'kapaa',
#  'amderma',
#  'bilma',
#  'liminangcong',
#  'elat',
#  'ilebo',
#  'amherst',
#  'evensk',
#  'cape town',
#  'port elizabeth',
#  'santa cruz',
#  'dubti',
#  'brae',
#  'xingcheng',
#  'albany',
#  'busselton',
#  'hualmay',
#  'tasiilaq',
#  'kurilsk',
#  'nouadhibou',
#  'saint anthony',
#  'barrow',
#  'qaanaaq',
#  'faanui',
#  'hilo',
#  'esperance',
#  'mataura',
#  'chaihe',
#  'sioux lookout',
#  'port alfred',
#  'bluff',
#  'attawapiskat',
#  'puerto ayora',
#  'eyrarbakki',
#  'pevek',
#  'ushuaia',
#  'kaitangata',
#  'bambous virieux',
#  'hermanus',
#  'hobart',
#  'illoqqortoormiut',
#  'lorengau',
#  'huilong',
#  'paamiut',
#  'takoradi',
#  'ixtapa',
#  'mehamn',
#  'barentsburg',
#  'san patricio',
#  'nikologory',
#  'santa vitoria do palmar',
#  'jumla',
#  'nikolskoye',
#  'sedan',
#  'mar del plata',
#  'waddan',
#  'thompson',
#  'broken hill',
#  'solnechnyy',
#  'aykhal',
#  'itaituba',
#  'hamilton',
#  'chokurdakh',
#  'itaqui',
#  'oussouye',
#  'iranshahr',
#  'manta',
#  'taolanaro',
#  'ribeira grande',
#  'margate',
#  'lusambo',
#  'georgetown',
#  'cherskiy',
#  'lolua',
#  'bossembele',
#  'bom jesus',
#  'lavrentiya',
#  'port lincoln',
#  'hithadhoo',
#  'lasa',
#  'gallup',
#  'toliary',
#  'atar',
#  'upernavik',
#  'sao filipe',
#  'ust-kamchatsk',
#  'goderich',
#  'shagonar',
#  'amambai',
#  'kruisfontein',
#  'alyangula',
#  'lebu',
#  'belushya guba',
#  'ancud',
#  'arraial do cabo',
#  'ocean city',
#  'bredasdorp',
#  'santa maria',
#  'jamestown',
#  'rosario',
#  'alofi',
#  'samusu',
#  'andenes',
#  'kerki',
#  'gollere',
#  'marsh harbour',
#  'airai',
#  'sentyabrskiy',
#  'norman wells',
#  'provideniya',
#  'springdale',
#  'san felipe',
#  'gazanjyk',
#  'florianopolis',
#  'saint-augustin',
#  'azuaga',
#  'severo-kurilsk',
#  'iqaluit',
#  'ostrovnoy',
#  'bethel',
#  'nguruka',
#  'vardo',
#  'kazalinsk',
#  'viedma',
#  'almaznyy',
#  'talas',
#  'chinsali',
#  'katobu',
#  'pisco',
#  'tezu',
#  'bairiki',
#  'ust-nera',
#  'broome',
#  'alice springs',
#  'raton',
#  'finschhafen',
#  'yellowknife',
#  'buraydah',
#  'geraldton',
#  'kodiak',
#  'mananjary',
#  'boende',
#  'salcioara',
#  'richards bay',
#  'irituia',
#  'cache creek',
#  'kajaani',
#  'awjilah',
#  'saldanha',
#  'ambilobe',
#  'maceio',
#  'skibbereen',
#  'mount vernon',
#  'yarke pole',
#  'half moon bay',
#  'necochea',
#  'inirida',
#  'makkaveyevo',
#  'kumbhraj',
#  'lewistown',
#  'chipinge',
#  'zaysan',
#  'port macquarie',
#  'pacific grove',
#  'mwinilunga',
#  'saleaula',
#  'taoudenni',
#  'adrar',
#  'port augusta',
#  'fernandez',
#  'dubbo',
#  'tumannyy',
#  'jutai',
#  'babanusah',
#  'konin',
#  'saint-philippe',
#  'emerald',
#  'victoria',
#  'lexington',
#  'vestmannaeyjar',
#  'thunder bay',
#  'sandpoint',
#  'kavaratti',
#  'muros',
#  'luderitz',
#  'nanortalik',
#  'vila franca do campo',
#  'cao bang',
#  'sint-genesius-rode',
#  'fairbanks',
#  'dhidhdhoo',
#  'kirakira',
#  'yar-sale',
#  'mapimi',
#  'sorland',
#  'souillac',
#  'prince rupert',
#  'chuy',
#  'moose factory',
#  'mys shmidta',
#  'beringovskiy',
#  'eqbaliyeh',
#  'vostok',
#  'koungou',
#  'caravelas',
#  'anadyr',
#  'zima',
#  'ponta delgada',
#  'karratha',
#  'turkistan',
#  'namatanai',
#  'muhos',
#  'saskylakh',
#  'columbus',
#  'loreto',
#  'east london',
#  'los llanos de aridane',
#  'marienburg',
#  'koumac',
#  'sinazongwe',
#  'saint-pierre',
#  'torbay',
#  'tommot',
#  'acapulco',
#  'pocone',
#  'umzimvubu',
#  'nemuro',
#  'dingle',
#  'cooma',
#  'hasaki',
#  'ilulissat',
#  'doha',
#  'cadillac',
#  'nalut',
#  'astana',
#  'hay river',
#  'riyadh',
#  'wairoa',
#  'lompoc',
#  'lago da pedra',
#  'osakarovka',
#  'tuktoyaktuk',
#  'kuche',
#  'san quintin',
#  'portland',
#  'kalmunai',
#  'colac',
#  'raga',
#  'flinders',
#  'bambanglipuro',
#  'great falls',
#  'aklavik',
#  'constantine',
#  'umm kaddadah',
#  'castro',
#  'nizhneyansk',
#  'nishihara',
#  'maloshuyka',
#  'benguela',
#  'meyungs',
#  'itatskiy',
#  'new norfolk',
#  'hopatcong',
#  'taksimo',
#  'babol',
#  'qazvin',
#  'zilair',
#  'ust-ilimsk',
#  'ugoofaaru',
#  'port hardy',
#  'mahebourg',
#  'lewisporte',
#  'pitimbu',
#  'taicheng',
#  'yanam',
#  'mmabatho',
#  'aksu',
#  'rio gallegos',
#  'waynesville',
#  'briancon',
#  'namibe',
#  'khatanga',
#  'kudahuvadhoo',
#  'hami',
#  'erenhot',
#  'constitucion',
#  'guerrero negro',
#  'sao felix do xingu',
#  'sarangani',
#  'scarborough',
#  'ponta do sol',
#  'wainwright',
#  'manokwari',
#  'karasuk',
#  'bievre',
#  'port hedland',
#  'suna',
#  'husavik',
#  'siva',
#  'marcona',
#  'escanaba',
#  'langsa',
#  'sobolevo',
#  'dandong',
#  'cernisoara',
#  'dikson',
#  'peniche',
#  'halifax',
#  'christchurch',
#  'merauke',
#  'sedelnikovo',
#  'malwan',
#  'sainte-maxime',
#  'cidreira',
#  'orebro',
#  'huron',
#  'pingdingshan',
#  'ghanzi',
#  'padang',
#  'tabas',
#  'bardiyah',
#  'kerema',
#  'navalmoral de la mata',
#  'shelburne',
#  'salinopolis',
#  'kokomo',
#  'synya',
#  'stornoway',
#  'tiksi',
#  'porto novo',
#  'nador',
#  'phitsanulok',
#  'eureka',
#  'ha giang',
#  'boda',
#  'gao',
#  'omaruru',
#  'touros',
#  'bathsheba',
#  'sidi qasim',
#  'tual',
#  'talnakh',
#  'gamboma',
#  'rapid valley',
#  'avarua',
#  'saint-georges',
#  'liberal',
#  'grand river south east',
#  'mahon',
#  'luoyang',
#  'roald',
#  'saryshagan',
#  'morgan city',
#  'charters towers',
#  'batticaloa',
#  'tawkar',
#  'boshkengash',
#  'okato',
#  'ordynskoye',
#  'houma',
#  'kidal',
#  'chagda',
#  'tura',
#  'barcelos',
#  'carnarvon',
#  'elban',
#  'banda aceh',
#  'mount isa',
#  'erdenet',
#  'upata',
#  'coihaique',
#  'lozuvatka',
#  'jijiga',
#  'tuatapere',
#  'quelimane',
#  'komsomolskiy',
#  'kungurtug',
#  'kalemie',
#  'freeport',
#  'dali',
#  'kawerau',
#  'tuggurt',
#  'istok',
#  'coquimbo',
#  'parana',
#  'prieska',
#  'gurgan',
#  'naze',
#  'asau',
#  'ngunguru',
#  'soto la marina',
#  'mayumba',
#  'alekseyevka',
#  'north shore',
#  'nagato',
#  'magadan',
#  'sakakah',
#  'narsaq',
#  'mizdah',
#  'mweka',
#  'van buren',
#  'bismarck',
#  'gouyave',
#  'kokuy',
#  'ardesen',
#  'pijijiapan',
#  'calama',
#  'waitara',
#  'omagh',
#  'whitianga',
#  'qaqortoq',
#  'san rafael',
#  'vaitupu',
#  'manjacaze',
#  'unye',
#  'beloha',
#  'braganca',
#  'brigantine',
#  'nome',
#  'avera',
#  'sohag',
#  'izberbash',
#  'kasongo-lunda',
#  'kununurra',
#  'tallahassee',
#  'daru',
#  'kahului',
#  'tsihombe',
#  'zyryanovsk',
#  'gawler',
#  'andreapol',
#  'yanchukan',
#  'anloga',
#  'port-gentil',
#  'novovasylivka',
#  'nata',
#  'iracoubo',
#  'bainbridge',
#  'puerto carreno',
#  'matara',
#  'basco',
#  'kibara',
#  'longyearbyen',
#  'sompeta',
#  'fez',
#  'rungata',
#  'northam',
#  'ibra',
#  'kuito',
#  'birjand',
#  'cayenne',
#  'divo',
#  'udachnyy',
#  'bayan',
#  'storozhevaya',
#  'sitka',
#  'whitehorse',
#  'shingu',
#  'president roxas',
#  'carahue',
#  'tres arroyos',
#  'palabuhanratu',
#  'kargil',
#  'emilio carranza',
#  'jalingo',
#  'khandyga',
#  'zelenoborsk',
#  'leningradskiy',
#  'moengo',
#  'swellendam',
#  'dauphin',
#  'miraflores',
#  'hearst',
#  'labutta',
#  'khobi',
#  'opuwo',
#  'omsukchan',
#  'rome',
#  'novovarshavka',
#  'potsdam',
#  'hofn',
#  'cap malheureux',
#  'baberu',
#  'kolokani',
#  'moree',
#  'havre-saint-pierre',
#  'road town',
#  'buka',
#  'konigs wusterhausen',
#  'lodja',
#  'talcahuano',
#  'khorixas',
#  'nurota',
#  'soledade',
#  'guia de isora',
#  'teguldet',
#  'purpe',
#  'tir pol',
#  'longlac',
#  'iwaki',
#  'kloulklubed',
#  'lagos',
#  'dunda',
#  'xiongzhou',
#  'pangnirtung',
#  'zhangye',
#  'kabare',
#  'te anau',
#  'luena',
#  'harper',
#  'jining',
#  'la rioja',
#  'lubsko',
#  'cabo san lucas',
#  'kibala',
#  'salalah',
#  'sieut',
#  'aflu',
#  'el carmen',
#  'zhigansk',
#  'vagamo',
#  'luganville',
#  'basoko',
#  'burgeo',
#  'chirongui',
#  'zlitan',
#  'altay',
#  'ussel',
#  'zhezkazgan',
#  'whyalla',
#  'ballina',
#  'lata',
#  'kjollefjord',
#  'amapa',
#  'jardim',
#  'amga',
#  'puro',
#  'lengshuitan',
#  'pak phanang',
#  'mikuni',
#  'antofagasta',
#  'port shepstone',
#  'coahuayana',
#  'port blair',
#  'sabha',
#  'srednekolymsk',
#  'buala',
#  'esmeralda',
#  'anchorage',
#  'issoudun',
#  'samarai',
#  'pingliang',
#  'north platte',
#  'dianopolis',
#  'erzin',
#  'colares',
#  'olafsvik',
#  'koraput',
#  'tarko-sale',
#  'bafq',
#  'oistins',
#  'tarudant',
#  'bokoro',
#  'nizhnevartovsk',
#  'tefe',
#  'college',
#  'muroto',
#  'kontagora',
#  'sinkat',
#  'teya',
#  'mandera',
#  'gabaldon',
#  'morehead',
#  'mecca',
#  'carballo',
#  'sibiti',
#  'bulgan',
#  'launceston',
#  'amazar',
#  'antalaha',
#  'yuyao',
#  'galveston',
#  'biak',
#  'sechura',
#  'tshikapa',
#  'kushima',
#  'codrington',
#  'agua dulce',
#  'lazaro cardenas',
#  'ironton']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
def create_sets(cities, chunk_size):
    for i in range(0, len(cities), chunk_size):
        yield cities[i: i + chunk_size]

# break down cities list into list of lists of size 50
chunk_size = 50
sets = create_sets(cities, chunk_size)

# get weather data from one city by calling API

def get_weather_data(city):
    
    url = "http://api.openweathermap.org/data/2.5/weather?"
    query_url = f"{url}appid={api_key}&q={city}"
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    return weather_json

# Run the loop for all sets

def run_all_cities(cities):    
    set_number = 1
    all_weather_data = []
    
    for set in sets:
        record = 1
        for city_value in set:
            weather_data = get_weather_data(city_value)
            weather_data

            # include format string into it along with try catch if city is not found

            if weather_data['cod'] == 200:
                print(f'Processing Record {record} of Set {set_number} | {city_value}')

                # Save data into another list
                all_weather_data.append(weather_data)

                record += 1
            else:             
                print('City not found. Skipping...')
        set_number += 1
    
    return all_weather_data
 
print("""-----------------------------
Beginning Data Retrieval      
-----------------------------""")

cities_weather_data = run_all_cities(sets)

print("""-----------------------------
Data Retrieval Complete      
-----------------------------""")
# Out:
# -----------------------------
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | turayf
# City not found. Skipping...
# Processing Record 2 of Set 1 | tupik
# Processing Record 3 of Set 1 | kavieng
# Processing Record 4 of Set 1 | north bend
# Processing Record 5 of Set 1 | youghal
# Processing Record 6 of Set 1 | vao
# Processing Record 7 of Set 1 | katsuura
# Processing Record 8 of Set 1 | hobyo
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | abha
# Processing Record 13 of Set 1 | poum
# Processing Record 14 of Set 1 | kenai
# Processing Record 15 of Set 1 | farrukhnagar
# Processing Record 16 of Set 1 | clearlake
# Processing Record 17 of Set 1 | buenos aires
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | santa lucia
# Processing Record 21 of Set 1 | emborion
# Processing Record 22 of Set 1 | kapaa
# City not found. Skipping...
# Processing Record 23 of Set 1 | bilma
# City not found. Skipping...
# Processing Record 24 of Set 1 | elat
# Processing Record 25 of Set 1 | ilebo
# Processing Record 26 of Set 1 | amherst
# Processing Record 27 of Set 1 | evensk
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | port elizabeth
# Processing Record 30 of Set 1 | santa cruz
# Processing Record 31 of Set 1 | dubti
# Processing Record 32 of Set 1 | brae
# Processing Record 33 of Set 1 | xingcheng
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | hualmay
# Processing Record 37 of Set 1 | tasiilaq
# Processing Record 38 of Set 1 | kurilsk
# Processing Record 39 of Set 1 | nouadhibou
# Processing Record 40 of Set 1 | saint anthony
# Processing Record 41 of Set 1 | barrow
# Processing Record 42 of Set 1 | qaanaaq
# Processing Record 43 of Set 1 | faanui
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | esperance
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | chaihe
# Processing Record 1 of Set 2 | sioux lookout
# Processing Record 2 of Set 2 | port alfred
# Processing Record 3 of Set 2 | bluff
# City not found. Skipping...
# Processing Record 4 of Set 2 | puerto ayora
# Processing Record 5 of Set 2 | eyrarbakki
# Processing Record 6 of Set 2 | pevek
# Processing Record 7 of Set 2 | ushuaia
# Processing Record 8 of Set 2 | kaitangata
# Processing Record 9 of Set 2 | bambous virieux
# Processing Record 10 of Set 2 | hermanus
# Processing Record 11 of Set 2 | hobart
# City not found. Skipping...
# Processing Record 12 of Set 2 | lorengau
# Processing Record 13 of Set 2 | huilong
# Processing Record 14 of Set 2 | paamiut
# Processing Record 15 of Set 2 | takoradi
# Processing Record 16 of Set 2 | ixtapa
# Processing Record 17 of Set 2 | mehamn
# City not found. Skipping...
# Processing Record 18 of Set 2 | san patricio
# Processing Record 19 of Set 2 | nikologory
# Processing Record 20 of Set 2 | santa vitoria do palmar
# Processing Record 21 of Set 2 | jumla
# Processing Record 22 of Set 2 | nikolskoye
# Processing Record 23 of Set 2 | sedan
# Processing Record 24 of Set 2 | mar del plata
# Processing Record 25 of Set 2 | waddan
# Processing Record 26 of Set 2 | thompson
# Processing Record 27 of Set 2 | broken hill
# Processing Record 28 of Set 2 | solnechnyy
# Processing Record 29 of Set 2 | aykhal
# Processing Record 30 of Set 2 | itaituba
# Processing Record 31 of Set 2 | hamilton
# Processing Record 32 of Set 2 | chokurdakh
# Processing Record 33 of Set 2 | itaqui
# Processing Record 34 of Set 2 | oussouye
# Processing Record 35 of Set 2 | iranshahr
# Processing Record 36 of Set 2 | manta
# City not found. Skipping...
# Processing Record 37 of Set 2 | ribeira grande
# Processing Record 38 of Set 2 | margate
# Processing Record 39 of Set 2 | lusambo
# Processing Record 40 of Set 2 | georgetown
# Processing Record 41 of Set 2 | cherskiy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 2 | bom jesus
# Processing Record 43 of Set 2 | lavrentiya
# Processing Record 44 of Set 2 | port lincoln
# Processing Record 1 of Set 3 | hithadhoo
# Processing Record 2 of Set 3 | lasa
# Processing Record 3 of Set 3 | gallup
# City not found. Skipping...
# Processing Record 4 of Set 3 | atar
# Processing Record 5 of Set 3 | upernavik
# Processing Record 6 of Set 3 | sao filipe
# City not found. Skipping...
# Processing Record 7 of Set 3 | goderich
# Processing Record 8 of Set 3 | shagonar
# Processing Record 9 of Set 3 | amambai
# Processing Record 10 of Set 3 | kruisfontein
# Processing Record 11 of Set 3 | alyangula
# Processing Record 12 of Set 3 | lebu
# City not found. Skipping...
# Processing Record 13 of Set 3 | ancud
# Processing Record 14 of Set 3 | arraial do cabo
# Processing Record 15 of Set 3 | ocean city
# Processing Record 16 of Set 3 | bredasdorp
# Processing Record 17 of Set 3 | santa maria
# Processing Record 18 of Set 3 | jamestown
# Processing Record 19 of Set 3 | rosario
# Processing Record 20 of Set 3 | alofi
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 21 of Set 3 | marsh harbour
# Processing Record 22 of Set 3 | airai
# City not found. Skipping...
# Processing Record 23 of Set 3 | norman wells
# Processing Record 24 of Set 3 | provideniya
# Processing Record 25 of Set 3 | springdale
# Processing Record 26 of Set 3 | san felipe
# Processing Record 27 of Set 3 | gazanjyk
# Processing Record 28 of Set 3 | florianopolis
# Processing Record 29 of Set 3 | saint-augustin
# Processing Record 30 of Set 3 | azuaga
# Processing Record 31 of Set 3 | severo-kurilsk
# Processing Record 32 of Set 3 | iqaluit
# Processing Record 33 of Set 3 | ostrovnoy
# Processing Record 34 of Set 3 | bethel
# Processing Record 35 of Set 3 | nguruka
# Processing Record 36 of Set 3 | vardo
# City not found. Skipping...
# Processing Record 37 of Set 3 | viedma
# Processing Record 38 of Set 3 | almaznyy
# Processing Record 39 of Set 3 | talas
# Processing Record 40 of Set 3 | chinsali
# Processing Record 41 of Set 3 | katobu
# Processing Record 1 of Set 4 | pisco
# Processing Record 2 of Set 4 | tezu
# City not found. Skipping...
# Processing Record 3 of Set 4 | ust-nera
# Processing Record 4 of Set 4 | broome
# Processing Record 5 of Set 4 | alice springs
# Processing Record 6 of Set 4 | raton
# Processing Record 7 of Set 4 | finschhafen
# Processing Record 8 of Set 4 | yellowknife
# Processing Record 9 of Set 4 | buraydah
# Processing Record 10 of Set 4 | geraldton
# Processing Record 11 of Set 4 | kodiak
# Processing Record 12 of Set 4 | mananjary
# Processing Record 13 of Set 4 | boende
# Processing Record 14 of Set 4 | salcioara
# Processing Record 15 of Set 4 | richards bay
# Processing Record 16 of Set 4 | irituia
# Processing Record 17 of Set 4 | cache creek
# Processing Record 18 of Set 4 | kajaani
# Processing Record 19 of Set 4 | awjilah
# Processing Record 20 of Set 4 | saldanha
# Processing Record 21 of Set 4 | ambilobe
# Processing Record 22 of Set 4 | maceio
# Processing Record 23 of Set 4 | skibbereen
# Processing Record 24 of Set 4 | mount vernon
# Processing Record 25 of Set 4 | yarke pole
# Processing Record 26 of Set 4 | half moon bay
# Processing Record 27 of Set 4 | necochea
# Processing Record 28 of Set 4 | inirida
# Processing Record 29 of Set 4 | makkaveyevo
# Processing Record 30 of Set 4 | kumbhraj
# Processing Record 31 of Set 4 | lewistown
# Processing Record 32 of Set 4 | chipinge
# Processing Record 33 of Set 4 | zaysan
# Processing Record 34 of Set 4 | port macquarie
# Processing Record 35 of Set 4 | pacific grove
# Processing Record 36 of Set 4 | mwinilunga
# City not found. Skipping...
# Processing Record 37 of Set 4 | taoudenni
# Processing Record 38 of Set 4 | adrar
# Processing Record 39 of Set 4 | port augusta
# Processing Record 40 of Set 4 | fernandez
# Processing Record 41 of Set 4 | dubbo
# City not found. Skipping...
# Processing Record 42 of Set 4 | jutai
# City not found. Skipping...
# Processing Record 43 of Set 4 | konin
# Processing Record 44 of Set 4 | saint-philippe
# Processing Record 45 of Set 4 | emerald
# Processing Record 46 of Set 4 | victoria
# Processing Record 1 of Set 5 | lexington
# Processing Record 2 of Set 5 | vestmannaeyjar
# Processing Record 3 of Set 5 | thunder bay
# Processing Record 4 of Set 5 | sandpoint
# Processing Record 5 of Set 5 | kavaratti
# Processing Record 6 of Set 5 | muros
# Processing Record 7 of Set 5 | luderitz
# Processing Record 8 of Set 5 | nanortalik
# Processing Record 9 of Set 5 | vila franca do campo
# Processing Record 10 of Set 5 | cao bang
# Processing Record 11 of Set 5 | sint-genesius-rode
# Processing Record 12 of Set 5 | fairbanks
# Processing Record 13 of Set 5 | dhidhdhoo
# Processing Record 14 of Set 5 | kirakira
# Processing Record 15 of Set 5 | yar-sale
# Processing Record 16 of Set 5 | mapimi
# Processing Record 17 of Set 5 | sorland
# Processing Record 18 of Set 5 | souillac
# Processing Record 19 of Set 5 | prince rupert
# Processing Record 20 of Set 5 | chuy
# Processing Record 21 of Set 5 | moose factory
# City not found. Skipping...
# Processing Record 22 of Set 5 | beringovskiy
# Processing Record 23 of Set 5 | eqbaliyeh
# Processing Record 24 of Set 5 | vostok
# City not found. Skipping...
# Processing Record 25 of Set 5 | caravelas
# Processing Record 26 of Set 5 | anadyr
# Processing Record 27 of Set 5 | zima
# Processing Record 28 of Set 5 | ponta delgada
# Processing Record 29 of Set 5 | karratha
# City not found. Skipping...
# Processing Record 30 of Set 5 | namatanai
# Processing Record 31 of Set 5 | muhos
# Processing Record 32 of Set 5 | saskylakh
# Processing Record 33 of Set 5 | columbus
# Processing Record 34 of Set 5 | loreto
# Processing Record 35 of Set 5 | east london
# Processing Record 36 of Set 5 | los llanos de aridane
# Processing Record 37 of Set 5 | marienburg
# Processing Record 38 of Set 5 | koumac
# Processing Record 39 of Set 5 | sinazongwe
# Processing Record 40 of Set 5 | saint-pierre
# Processing Record 41 of Set 5 | torbay
# Processing Record 42 of Set 5 | tommot
# Processing Record 43 of Set 5 | acapulco
# Processing Record 44 of Set 5 | pocone
# City not found. Skipping...
# Processing Record 45 of Set 5 | nemuro
# Processing Record 46 of Set 5 | dingle
# Processing Record 1 of Set 6 | cooma
# Processing Record 2 of Set 6 | hasaki
# Processing Record 3 of Set 6 | ilulissat
# Processing Record 4 of Set 6 | doha
# Processing Record 5 of Set 6 | cadillac
# Processing Record 6 of Set 6 | nalut
# Processing Record 7 of Set 6 | astana
# Processing Record 8 of Set 6 | hay river
# Processing Record 9 of Set 6 | riyadh
# Processing Record 10 of Set 6 | wairoa
# Processing Record 11 of Set 6 | lompoc
# City not found. Skipping...
# Processing Record 12 of Set 6 | osakarovka
# Processing Record 13 of Set 6 | tuktoyaktuk
# City not found. Skipping...
# Processing Record 14 of Set 6 | san quintin
# Processing Record 15 of Set 6 | portland
# Processing Record 16 of Set 6 | kalmunai
# Processing Record 17 of Set 6 | colac
# City not found. Skipping...
# Processing Record 18 of Set 6 | flinders
# Processing Record 19 of Set 6 | bambanglipuro
# Processing Record 20 of Set 6 | great falls
# Processing Record 21 of Set 6 | aklavik
# Processing Record 22 of Set 6 | constantine
# Processing Record 23 of Set 6 | umm kaddadah
# Processing Record 24 of Set 6 | castro
# City not found. Skipping...
# Processing Record 25 of Set 6 | nishihara
# City not found. Skipping...
# Processing Record 26 of Set 6 | benguela
# City not found. Skipping...
# Processing Record 27 of Set 6 | itatskiy
# Processing Record 28 of Set 6 | new norfolk
# Processing Record 29 of Set 6 | hopatcong
# Processing Record 30 of Set 6 | taksimo
# Processing Record 31 of Set 6 | babol
# Processing Record 32 of Set 6 | qazvin
# Processing Record 33 of Set 6 | zilair
# Processing Record 34 of Set 6 | ust-ilimsk
# Processing Record 35 of Set 6 | ugoofaaru
# Processing Record 36 of Set 6 | port hardy
# Processing Record 37 of Set 6 | mahebourg
# Processing Record 38 of Set 6 | lewisporte
# Processing Record 39 of Set 6 | pitimbu
# Processing Record 40 of Set 6 | taicheng
# Processing Record 41 of Set 6 | yanam
# Processing Record 42 of Set 6 | mmabatho
# Processing Record 43 of Set 6 | aksu
# Processing Record 44 of Set 6 | rio gallegos
# Processing Record 1 of Set 7 | waynesville
# Processing Record 2 of Set 7 | briancon
# Processing Record 3 of Set 7 | namibe
# Processing Record 4 of Set 7 | khatanga
# Processing Record 5 of Set 7 | kudahuvadhoo
# Processing Record 6 of Set 7 | hami
# Processing Record 7 of Set 7 | erenhot
# Processing Record 8 of Set 7 | constitucion
# Processing Record 9 of Set 7 | guerrero negro
# Processing Record 10 of Set 7 | sao felix do xingu
# Processing Record 11 of Set 7 | sarangani
# Processing Record 12 of Set 7 | scarborough
# Processing Record 13 of Set 7 | ponta do sol
# Processing Record 14 of Set 7 | wainwright
# Processing Record 15 of Set 7 | manokwari
# Processing Record 16 of Set 7 | karasuk
# Processing Record 17 of Set 7 | bievre
# Processing Record 18 of Set 7 | port hedland
# Processing Record 19 of Set 7 | suna
# Processing Record 20 of Set 7 | husavik
# Processing Record 21 of Set 7 | siva
# City not found. Skipping...
# Processing Record 22 of Set 7 | escanaba
# Processing Record 23 of Set 7 | langsa
# Processing Record 24 of Set 7 | sobolevo
# Processing Record 25 of Set 7 | dandong
# Processing Record 26 of Set 7 | cernisoara
# Processing Record 27 of Set 7 | dikson
# Processing Record 28 of Set 7 | peniche
# Processing Record 29 of Set 7 | halifax
# Processing Record 30 of Set 7 | christchurch
# Processing Record 31 of Set 7 | merauke
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 32 of Set 7 | sainte-maxime
# Processing Record 33 of Set 7 | cidreira
# Processing Record 34 of Set 7 | orebro
# Processing Record 35 of Set 7 | huron
# Processing Record 36 of Set 7 | pingdingshan
# Processing Record 37 of Set 7 | ghanzi
# Processing Record 38 of Set 7 | padang
# Processing Record 39 of Set 7 | tabas
# City not found. Skipping...
# Processing Record 40 of Set 7 | kerema
# Processing Record 41 of Set 7 | navalmoral de la mata
# Processing Record 42 of Set 7 | shelburne
# Processing Record 43 of Set 7 | salinopolis
# Processing Record 44 of Set 7 | kokomo
# Processing Record 45 of Set 7 | synya
# City not found. Skipping...
# Processing Record 1 of Set 8 | tiksi
# Processing Record 2 of Set 8 | porto novo
# Processing Record 3 of Set 8 | nador
# Processing Record 4 of Set 8 | phitsanulok
# Processing Record 5 of Set 8 | eureka
# Processing Record 6 of Set 8 | ha giang
# Processing Record 7 of Set 8 | boda
# Processing Record 8 of Set 8 | gao
# Processing Record 9 of Set 8 | omaruru
# Processing Record 10 of Set 8 | touros
# Processing Record 11 of Set 8 | bathsheba
# City not found. Skipping...
# Processing Record 12 of Set 8 | tual
# Processing Record 13 of Set 8 | talnakh
# Processing Record 14 of Set 8 | gamboma
# Processing Record 15 of Set 8 | rapid valley
# Processing Record 16 of Set 8 | avarua
# Processing Record 17 of Set 8 | saint-georges
# Processing Record 18 of Set 8 | liberal
# City not found. Skipping...
# Processing Record 19 of Set 8 | mahon
# Processing Record 20 of Set 8 | luoyang
# Processing Record 21 of Set 8 | roald
# City not found. Skipping...
# Processing Record 22 of Set 8 | morgan city
# Processing Record 23 of Set 8 | charters towers
# Processing Record 24 of Set 8 | batticaloa
# City not found. Skipping...
# Processing Record 25 of Set 8 | boshkengash
# Processing Record 26 of Set 8 | okato
# Processing Record 27 of Set 8 | ordynskoye
# Processing Record 28 of Set 8 | houma
# Processing Record 29 of Set 8 | kidal
# City not found. Skipping...
# Processing Record 30 of Set 8 | tura
# Processing Record 31 of Set 8 | barcelos
# Processing Record 32 of Set 8 | carnarvon
# Processing Record 33 of Set 8 | elban
# Processing Record 34 of Set 8 | banda aceh
# Processing Record 35 of Set 8 | mount isa
# Processing Record 36 of Set 8 | erdenet
# Processing Record 37 of Set 8 | upata
# Processing Record 38 of Set 8 | coihaique
# Processing Record 39 of Set 8 | lozuvatka
# Processing Record 40 of Set 8 | jijiga
# Processing Record 41 of Set 8 | tuatapere
# Processing Record 42 of Set 8 | quelimane
# Processing Record 43 of Set 8 | komsomolskiy
# Processing Record 44 of Set 8 | kungurtug
# Processing Record 45 of Set 8 | kalemie
# Processing Record 1 of Set 9 | freeport
# Processing Record 2 of Set 9 | dali
# Processing Record 3 of Set 9 | kawerau
# City not found. Skipping...
# Processing Record 4 of Set 9 | istok
# Processing Record 5 of Set 9 | coquimbo
# Processing Record 6 of Set 9 | parana
# Processing Record 7 of Set 9 | prieska
# City not found. Skipping...
# Processing Record 8 of Set 9 | naze
# City not found. Skipping...
# Processing Record 9 of Set 9 | ngunguru
# Processing Record 10 of Set 9 | soto la marina
# Processing Record 11 of Set 9 | mayumba
# Processing Record 12 of Set 9 | alekseyevka
# Processing Record 13 of Set 9 | north shore
# Processing Record 14 of Set 9 | nagato
# Processing Record 15 of Set 9 | magadan
# City not found. Skipping...
# Processing Record 16 of Set 9 | narsaq
# Processing Record 17 of Set 9 | mizdah
# Processing Record 18 of Set 9 | mweka
# Processing Record 19 of Set 9 | van buren
# Processing Record 20 of Set 9 | bismarck
# Processing Record 21 of Set 9 | gouyave
# Processing Record 22 of Set 9 | kokuy
# Processing Record 23 of Set 9 | ardesen
# Processing Record 24 of Set 9 | pijijiapan
# Processing Record 25 of Set 9 | calama
# Processing Record 26 of Set 9 | waitara
# Processing Record 27 of Set 9 | omagh
# Processing Record 28 of Set 9 | whitianga
# Processing Record 29 of Set 9 | qaqortoq
# Processing Record 30 of Set 9 | san rafael
# City not found. Skipping...
# Processing Record 31 of Set 9 | manjacaze
# City not found. Skipping...
# Processing Record 32 of Set 9 | beloha
# Processing Record 33 of Set 9 | braganca
# Processing Record 34 of Set 9 | brigantine
# Processing Record 35 of Set 9 | nome
# Processing Record 36 of Set 9 | avera
# Processing Record 37 of Set 9 | sohag
# Processing Record 38 of Set 9 | izberbash
# Processing Record 39 of Set 9 | kasongo-lunda
# Processing Record 40 of Set 9 | kununurra
# Processing Record 41 of Set 9 | tallahassee
# Processing Record 42 of Set 9 | daru
# Processing Record 43 of Set 9 | kahului
# City not found. Skipping...
# Processing Record 1 of Set 10 | zyryanovsk
# Processing Record 2 of Set 10 | gawler
# Processing Record 3 of Set 10 | andreapol
# City not found. Skipping...
# Processing Record 4 of Set 10 | anloga
# Processing Record 5 of Set 10 | port-gentil
# Processing Record 6 of Set 10 | novovasylivka
# Processing Record 7 of Set 10 | nata
# Processing Record 8 of Set 10 | iracoubo
# Processing Record 9 of Set 10 | bainbridge
# Processing Record 10 of Set 10 | puerto carreno
# Processing Record 11 of Set 10 | matara
# Processing Record 12 of Set 10 | basco
# Processing Record 13 of Set 10 | kibara
# Processing Record 14 of Set 10 | longyearbyen
# Processing Record 15 of Set 10 | sompeta
# Processing Record 16 of Set 10 | fez
# City not found. Skipping...
# Processing Record 17 of Set 10 | northam
# Processing Record 18 of Set 10 | ibra
# Processing Record 19 of Set 10 | kuito
# Processing Record 20 of Set 10 | birjand
# Processing Record 21 of Set 10 | cayenne
# Processing Record 22 of Set 10 | divo
# Processing Record 23 of Set 10 | udachnyy
# Processing Record 24 of Set 10 | bayan
# Processing Record 25 of Set 10 | storozhevaya
# Processing Record 26 of Set 10 | sitka
# Processing Record 27 of Set 10 | whitehorse
# Processing Record 28 of Set 10 | shingu
# Processing Record 29 of Set 10 | president roxas
# Processing Record 30 of Set 10 | carahue
# Processing Record 31 of Set 10 | tres arroyos
# City not found. Skipping...
# Processing Record 32 of Set 10 | kargil
# Processing Record 33 of Set 10 | emilio carranza
# Processing Record 34 of Set 10 | jalingo
# Processing Record 35 of Set 10 | khandyga
# Processing Record 36 of Set 10 | zelenoborsk
# Processing Record 37 of Set 10 | leningradskiy
# Processing Record 38 of Set 10 | moengo
# Processing Record 39 of Set 10 | swellendam
# Processing Record 40 of Set 10 | dauphin
# Processing Record 41 of Set 10 | miraflores
# Processing Record 42 of Set 10 | hearst
# City not found. Skipping...
# Processing Record 43 of Set 10 | khobi
# Processing Record 44 of Set 10 | opuwo
# Processing Record 45 of Set 10 | omsukchan
# Processing Record 46 of Set 10 | rome
# Processing Record 1 of Set 11 | novovarshavka
# Processing Record 2 of Set 11 | potsdam
# Processing Record 3 of Set 11 | hofn
# Processing Record 4 of Set 11 | cap malheureux
# Processing Record 5 of Set 11 | baberu
# Processing Record 6 of Set 11 | kolokani
# Processing Record 7 of Set 11 | moree
# Processing Record 8 of Set 11 | havre-saint-pierre
# Processing Record 9 of Set 11 | road town
# Processing Record 10 of Set 11 | buka
# Processing Record 11 of Set 11 | konigs wusterhausen
# Processing Record 12 of Set 11 | lodja
# Processing Record 13 of Set 11 | talcahuano
# Processing Record 14 of Set 11 | khorixas
# Processing Record 15 of Set 11 | nurota
# Processing Record 16 of Set 11 | soledade
# Processing Record 17 of Set 11 | guia de isora
# Processing Record 18 of Set 11 | teguldet
# Processing Record 19 of Set 11 | purpe
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 20 of Set 11 | iwaki
# Processing Record 21 of Set 11 | kloulklubed
# Processing Record 22 of Set 11 | lagos
# Processing Record 23 of Set 11 | dunda
# Processing Record 24 of Set 11 | xiongzhou
# Processing Record 25 of Set 11 | pangnirtung
# Processing Record 26 of Set 11 | zhangye
# Processing Record 27 of Set 11 | kabare
# Processing Record 28 of Set 11 | te anau
# Processing Record 29 of Set 11 | luena
# Processing Record 30 of Set 11 | harper
# Processing Record 31 of Set 11 | jining
# Processing Record 32 of Set 11 | la rioja
# Processing Record 33 of Set 11 | lubsko
# Processing Record 34 of Set 11 | cabo san lucas
# Processing Record 35 of Set 11 | kibala
# Processing Record 36 of Set 11 | salalah
# Processing Record 37 of Set 11 | sieut
# City not found. Skipping...
# Processing Record 38 of Set 11 | el carmen
# Processing Record 39 of Set 11 | zhigansk
# Processing Record 40 of Set 11 | vagamo
# Processing Record 41 of Set 11 | luganville
# Processing Record 42 of Set 11 | basoko
# Processing Record 43 of Set 11 | burgeo
# Processing Record 44 of Set 11 | chirongui
# Processing Record 45 of Set 11 | zlitan
# Processing Record 46 of Set 11 | altay
# Processing Record 47 of Set 11 | ussel
# Processing Record 1 of Set 12 | zhezkazgan
# Processing Record 2 of Set 12 | whyalla
# Processing Record 3 of Set 12 | ballina
# Processing Record 4 of Set 12 | lata
# Processing Record 5 of Set 12 | kjollefjord
# Processing Record 6 of Set 12 | amapa
# Processing Record 7 of Set 12 | jardim
# Processing Record 8 of Set 12 | amga
# Processing Record 9 of Set 12 | puro
# Processing Record 10 of Set 12 | lengshuitan
# Processing Record 11 of Set 12 | pak phanang
# Processing Record 12 of Set 12 | mikuni
# Processing Record 13 of Set 12 | antofagasta
# Processing Record 14 of Set 12 | port shepstone
# Processing Record 15 of Set 12 | coahuayana
# Processing Record 16 of Set 12 | port blair
# Processing Record 17 of Set 12 | sabha
# Processing Record 18 of Set 12 | srednekolymsk
# Processing Record 19 of Set 12 | buala
# Processing Record 20 of Set 12 | esmeralda
# Processing Record 21 of Set 12 | anchorage
# Processing Record 22 of Set 12 | issoudun
# Processing Record 23 of Set 12 | samarai
# Processing Record 24 of Set 12 | pingliang
# Processing Record 25 of Set 12 | north platte
# City not found. Skipping...
# Processing Record 26 of Set 12 | erzin
# Processing Record 27 of Set 12 | colares
# City not found. Skipping...
# Processing Record 28 of Set 12 | koraput
# Processing Record 29 of Set 12 | tarko-sale
# Processing Record 30 of Set 12 | bafq
# Processing Record 31 of Set 12 | oistins
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 32 of Set 12 | nizhnevartovsk
# Processing Record 33 of Set 12 | tefe
# Processing Record 34 of Set 12 | college
# Processing Record 35 of Set 12 | muroto
# Processing Record 36 of Set 12 | kontagora
# City not found. Skipping...
# Processing Record 37 of Set 12 | teya
# Processing Record 38 of Set 12 | mandera
# Processing Record 39 of Set 12 | gabaldon
# Processing Record 40 of Set 12 | morehead
# Processing Record 41 of Set 12 | mecca
# Processing Record 42 of Set 12 | carballo
# Processing Record 43 of Set 12 | sibiti
# Processing Record 44 of Set 12 | bulgan
# Processing Record 45 of Set 12 | launceston
# Processing Record 1 of Set 13 | amazar
# Processing Record 2 of Set 13 | antalaha
# Processing Record 3 of Set 13 | yuyao
# Processing Record 4 of Set 13 | galveston
# Processing Record 5 of Set 13 | biak
# Processing Record 6 of Set 13 | sechura
# Processing Record 7 of Set 13 | tshikapa
# Processing Record 8 of Set 13 | kushima
# Processing Record 9 of Set 13 | codrington
# Processing Record 10 of Set 13 | agua dulce
# Processing Record 11 of Set 13 | lazaro cardenas
# Processing Record 12 of Set 13 | ironton
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
def mapper(dict):
    return {
        'City': row['name'],
        'Cloudiness' : row['clouds']['all'],
        'Country': row['sys']['country'],
        'Date': row['dt'],
        'Humidity': row['main']['humidity'],
        'Lat': row['coord']['lat'],
        'Lng': row['coord']['lon'],
        'Max Temp': row['main']['temp_max'],
        'Wind Speed': row['wind']['speed']        
    }


city_weather_list = []

for row in cities_weather_data:
    city = mapper(row)
    city_weather_list.append(city)

city_weather_list
# Out:
# [{'City': 'Turayf',
#   'Cloudiness': 0,
#   'Country': 'SA',
#   'Date': 1569561251,
#   'Humidity': 34,
#   'Lat': 31.68,
#   'Lng': 38.65,
#   'Max Temp': 291.15,
#   'Wind Speed': 3.1},
#  {'City': 'Tupik',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1569561252,
#   'Humidity': 91,
#   'Lat': 54.43,
#   'Lng': 119.94,
#   'Max Temp': 283.482,
#   'Wind Speed': 1.31},
#  {'City': 'Kavieng',
#   'Cloudiness': 65,
#   'Country': 'PG',
#   'Date': 1569561252,
#   'Humidity': 73,
#   'Lat': -2.57,
#   'Lng': 150.8,
#   'Max Temp': 302.222,
#   'Wind Speed': 4.92},
#  {'City': 'North Bend',
#   'Cloudiness': 75,
#   'Country': 'US',
#   'Date': 1569561252,
#   'Humidity': 82,
#   'Lat': 43.41,
#   'Lng': -124.22,
#   'Max Temp': 288.71,
#   'Wind Speed': 3.1},
#  {'City': 'Youghal',
#   'Cloudiness': 75,
#   'Country': 'IE',
#   'Date': 1569561252,
#   'Humidity': 93,
#   'Lat': 51.95,
#   'Lng': -7.85,
#   'Max Temp': 287.59,
#   'Wind Speed': 8.2},
#  {'City': 'Vao',
#   'Cloudiness': 44,
#   'Country': 'EE',
#   'Date': 1569561253,
#   'Humidity': 88,
#   'Lat': 59.1,
#   'Lng': 26.19,
#   'Max Temp': 280.742,
#   'Wind Speed': 2.31},
#  {'City': 'Katsuura',
#   'Cloudiness': 75,
#   'Country': 'JP',
#   'Date': 1569561253,
#   'Humidity': 78,
#   'Lat': 33.93,
#   'Lng': 134.5,
#   'Max Temp': 302.04,
#   'Wind Speed': 7.2},
#  {'City': 'Hobyo',
#   'Cloudiness': 34,
#   'Country': 'SO',
#   'Date': 1569561253,
#   'Humidity': 52,
#   'Lat': 5.35,
#   'Lng': 48.53,
#   'Max Temp': 303.142,
#   'Wind Speed': 8.4},
#  {'City': 'Punta Arenas',
#   'Cloudiness': 0,
#   'Country': 'CL',
#   'Date': 1569561253,
#   'Humidity': 52,
#   'Lat': -53.16,
#   'Lng': -70.91,
#   'Max Temp': 280.93,
#   'Wind Speed': 7.2},
#  {'City': 'Butaritari',
#   'Cloudiness': 0,
#   'Country': 'KI',
#   'Date': 1569561254,
#   'Humidity': 57,
#   'Lat': 3.07,
#   'Lng': 172.79,
#   'Max Temp': 302.912,
#   'Wind Speed': 4.07},
#  {'City': 'Atuona',
#   'Cloudiness': 8,
#   'Country': 'PF',
#   'Date': 1569561254,
#   'Humidity': 74,
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Max Temp': 299.502,
#   'Wind Speed': 7.26},
#  {'City': 'Abha',
#   'Cloudiness': 0,
#   'Country': 'SA',
#   'Date': 1569561254,
#   'Humidity': 55,
#   'Lat': 18.22,
#   'Lng': 42.5,
#   'Max Temp': 293.15,
#   'Wind Speed': 2.6},
#  {'City': 'Poum',
#   'Cloudiness': 75,
#   'Country': 'MK',
#   'Date': 1569561254,
#   'Humidity': 87,
#   'Lat': 41.28,
#   'Lng': 20.71,
#   'Max Temp': 283.15,
#   'Wind Speed': 2.1},
#  {'City': 'Kenai',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1569561006,
#   'Humidity': 65,
#   'Lat': 60.55,
#   'Lng': -151.26,
#   'Max Temp': 280.15,
#   'Wind Speed': 2.06},
#  {'City': 'Farrukhnagar',
#   'Cloudiness': 75,
#   'Country': 'IN',
#   'Date': 1569561255,
#   'Humidity': 78,
#   'Lat': 28.45,
#   'Lng': 76.82,
#   'Max Temp': 303.71,
#   'Wind Speed': 3.1},
#  {'City': 'Clearlake',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1569561255,
#   'Humidity': 77,
#   'Lat': 38.96,
#   'Lng': -122.63,
#   'Max Temp': 292.04,
#   'Wind Speed': 1.22},
#  {'City': 'Buenos Aires',
#   'Cloudiness': 0,
#   'Country': 'AR',
#   'Date': 1569561255,
#   'Humidity': 77,
#   'Lat': -34.61,
#   'Lng': -58.44,
#   'Max Temp': 288.15,
#   'Wind Speed': 7.2},
#  {'City': 'Rikitea',
#   'Cloudiness': 20,
#   'Country': 'PF',
#   'Date': 1569561255,
#   'Humidity': 73,
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max Temp': 295.312,
#   'Wind Speed': 4.95},
#  {'City': 'Vaini',
#   'Cloudiness': 75,
#   'Country': 'IN',
#   'Date': 1569561256,
#   'Humidity': 94,
#   'Lat': 15.34,
#   'Lng': 74.49,
#   'Max Temp': 297.15,
#   'Wind Speed': 5.1},
#  {'City': 'Santa Lucia',
#   'Cloudiness': 0,
#   'Country': 'IT',
#   'Date': 1569561256,
#   'Humidity': 82,
#   'Lat': 41.98,
#   'Lng': 12.66,
#   'Max Temp': 291.48,
#   'Wind Speed': 1},
#  {'City': 'Emborion',
#   'Cloudiness': 14,
#   'Country': 'GR',
#   'Date': 1569561256,
#   'Humidity': 27,
#   'Lat': 40.48,
#   'Lng': 21.55,
#   'Max Temp': 291.48,
#   'Wind Speed': 3.58},
#  {'City': 'Kapaa',
#   'Cloudiness': 75,
#   'Country': 'US',
#   'Date': 1569560966,
#   'Humidity': 83,
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Max Temp': 301.15,
#   'Wind Speed': 4.1},
#  {'City': 'Bilma',
#   'Cloudiness': 0,
#   'Country': 'NE',
#   'Date': 1569561257,
#   'Humidity': 12,
#   'Lat': 18.69,
#   'Lng': 12.92,
#   'Max Temp': 301.172,
#   'Wind Speed': 4.47},
#  {'City': 'Elat',
#   'Cloudiness': 89,
#   'Country': 'CM',
#   'Date': 1569561257,
#   'Humidity': 95,
#   'Lat': 2.91,
#   'Lng': 11.16,
#   'Max Temp': 293.862,
#   'Wind Speed': 1.27},
#  {'City': 'Ilebo',
#   'Cloudiness': 100,
#   'Country': 'CD',
#   'Date': 1569561257,
#   'Humidity': 88,
#   'Lat': -4.33,
#   'Lng': 20.59,
#   'Max Temp': 296.152,
#   'Wind Speed': 0.25},
#  {'City': 'Amherst',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1569561257,
#   'Humidity': 81,
#   'Lat': 42.98,
#   'Lng': -78.8,
#   'Max Temp': 284.82,
#   'Wind Speed': 2.62},
#  {'City': 'Evensk',
#   'Cloudiness': 64,
#   'Country': 'RU',
#   'Date': 1569561258,
#   'Humidity': 53,
#   'Lat': 61.92,
#   'Lng': 159.24,
#   'Max Temp': 278.992,
#   'Wind Speed': 2.55},
#  {'City': 'Cape Town',
#   'Cloudiness': 8,
#   'Country': 'ZA',
#   'Date': 1569561002,
#   'Humidity': 93,
#   'Lat': -33.93,
#   'Lng': 18.42,
#   'Max Temp': 292.59,
#   'Wind Speed': 2.6},
#  {'City': 'Port Elizabeth',
#   'Cloudiness': 0,
#   'Country': 'US',
#   'Date': 1569561258,
#   'Humidity': 93,
#   'Lat': 39.31,
#   'Lng': -74.98,
#   'Max Temp': 293.71,
#   'Wind Speed': 1.83},
#  {'City': 'Santa Cruz',
#   'Cloudiness': 19,
#   'Country': 'BR',
#   'Date': 1569561258,
#   'Humidity': 93,
#   'Lat': -6.22,
#   'Lng': -36.02,
#   'Max Temp': 291.952,
#   'Wind Speed': 2.41},
#  {'City': 'Dubti',
#   'Cloudiness': 25,
#   'Country': 'ET',
#   'Date': 1569561258,
#   'Humidity': 33,
#   'Lat': 11.74,
#   'Lng': 41.09,
#   'Max Temp': 306.982,
#   'Wind Speed': 0.36},
#  {'City': 'Brae',
#   'Cloudiness': 20,
#   'Country': 'GB',
#   'Date': 1569561259,
#   'Humidity': 93,
#   'Lat': 60.4,
#   'Lng': -1.35,
#   'Max Temp': 285.15,
#   'Wind Speed': 7.2},
#  {'City': 'Xingcheng',
#   'Cloudiness': 0,
#   'Country': 'CN',
#   'Date': 1569561259,
#   'Humidity': 51,
#   'Lat': 40.62,
#   'Lng': 120.71,
#   'Max Temp': 298.322,
#   'Wind Speed': 5.34},
#  {'City': 'Albany',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1569561115,
#   'Humidity': 93,
#   'Lat': 42.65,
#   'Lng': -73.75,
#   'Max Temp': 285.37,
#   'Wind Speed': 2.38},
#  {'City': 'Busselton',
#   'Cloudiness': 49,
#   'Country': 'AU',
#   'Date': 1569561259,
#   'Humidity': 40,
#   'Lat': -33.64,
#   'Lng': 115.35,
#   'Max Temp': 294.26,
#   'Wind Speed': 3.59},
#  {'City': 'Hualmay',
#   'Cloudiness': 13,
#   'Country': 'PE',
#   'Date': 1569561259,
#   'Humidity': 92,
#   'Lat': -11.1,
#   'Lng': -77.61,
#   'Max Temp': 289.022,
#   'Wind Speed': 5.6},
#  {'City': 'Tasiilaq',
#   'Cloudiness': 100,
#   'Country': 'GL',
#   'Date': 1569561260,
#   'Humidity': 86,
#   'Lat': 65.61,
#   'Lng': -37.64,
#   'Max Temp': 276.15,
#   'Wind Speed': 2.6},
#  {'City': 'Kurilsk',
#   'Cloudiness': 0,
#   'Country': 'RU',
#   'Date': 1569561260,
#   'Humidity': 60,
#   'Lat': 45.23,
#   'Lng': 147.88,
#   'Max Temp': 287.062,
#   'Wind Speed': 6.06},
#  {'City': 'Nouadhibou',
#   'Cloudiness': 0,
#   'Country': 'MR',
#   'Date': 1569561260,
#   'Humidity': 88,
#   'Lat': 20.93,
#   'Lng': -17.03,
#   'Max Temp': 293.15,
#   'Wind Speed': 8.7},
#  {'City': 'Saint Anthony',
#   'Cloudiness': 75,
#   'Country': 'US',
#   'Date': 1569561260,
#   'Humidity': 54,
#   'Lat': 43.97,
#   'Lng': -111.68,
#   'Max Temp': 291.15,
#   'Wind Speed': 3.6},
#  {'City': 'Barrow',
#   'Cloudiness': 100,
#   'Country': 'AR',
#   'Date': 1569561261,
#   'Humidity': 65,
#   'Lat': -38.31,
#   'Lng': -60.23,
#   'Max Temp': 279.572,
#   'Wind Speed': 4.29},
#  {'City': 'Qaanaaq',
#   'Cloudiness': 100,
#   'Country': 'GL',
#   'Date': 1569561261,
#   'Humidity': 97,
#   'Lat': 77.48,
#   'Lng': -69.36,
#   'Max Temp': 273.122,
#   'Wind Speed': 8.04},
#  {'City': 'Faanui',
#   'Cloudiness': 84,
#   'Country': 'PF',
#   'Date': 1569561261,
#   'Humidity': 80,
#   'Lat': -16.48,
#   'Lng': -151.75,
#   'Max Temp': 299.602,
#   'Wind Speed': 6.4},
#  {'City': 'Hilo',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1569561261,
#   'Humidity': 70,
#   'Lat': 19.71,
#   'Lng': -155.08,
#   'Max Temp': 302.15,
#   'Wind Speed': 3.1},
#  {'City': 'Esperance',
#   'Cloudiness': 75,
#   'Country': 'AU',
#   'Date': 1569561262,
#   'Humidity': 87,
#   'Lat': -33.86,
#   'Lng': 121.89,
#   'Max Temp': 288.15,
#   'Wind Speed': 3.6},
#  {'City': 'Mataura',
#   'Cloudiness': 43,
#   'Country': 'NZ',
#   'Date': 1569561262,
#   'Humidity': 80,
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Max Temp': 284.82,
#   'Wind Speed': 8.05},
#  {'City': 'Chaihe',
#   'Cloudiness': 0,
#   'Country': 'CN',
#   'Date': 1569561262,
#   'Humidity': 41,
#   'Lat': 44.77,
#   'Lng': 129.68,
#   'Max Temp': 298.572,
#   'Wind Speed': 2.84},
#  {'City': 'Sioux Lookout',
#   'Cloudiness': 90,
#   'Country': 'CA',
#   'Date': 1569561262,
#   'Humidity': 93,
#   'Lat': 50.1,
#   'Lng': -91.92,
#   'Max Temp': 281.15,
#   'Wind Speed': 2.6},
#  {'City': 'Port Alfred',
#   'Cloudiness': 0,
#   'Country': 'ZA',
#   'Date': 1569561262,
#   'Humidity': 41,
#   'Lat': -33.59,
#   'Lng': 26.89,
#   'Max Temp': 295.37,
#   'Wind Speed': 4.61},
#  {'City': 'Bluff',
#   'Cloudiness': 10,
#   'Country': 'AU',
#   'Date': 1569561263,
#   'Humidity': 25,
#   'Lat': -23.58,
#   'Lng': 149.07,
#   'Max Temp': 303.182,
#   'Wind Speed': 3.35},
#  {'City': 'Puerto Ayora',
#   'Cloudiness': 23,
#   'Country': 'EC',
#   'Date': 1569561263,
#   'Humidity': 87,
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Max Temp': 293.15,
#   'Wind Speed': 1.34},
#  {'City': 'Eyrarbakki',
#   'Cloudiness': 0,
#   'Country': 'IS',
#   'Date': 1569561263,
#   'Humidity': 71,
#   'Lat': 63.86,
#   'Lng': -21.15,
#   'Max Temp': 285.15,
#   'Wind Speed': 2.1},
#  {'City': 'Pevek',
#   'Cloudiness': 95,
#   'Country': 'RU',
#   'Date': 1569561263,
#   'Humidity': 79,
#   'Lat': 69.7,
#   'Lng': 170.27,
#   'Max Temp': 274.752,
#   'Wind Speed': 9.45},
#  {'City': 'Ushuaia',
#   'Cloudiness': 75,
#   'Country': 'AR',
#   'Date': 1569561264,
#   'Humidity': 75,
#   'Lat': -54.81,
#   'Lng': -68.31,
#   'Max Temp': 279.15,
#   'Wind Speed': 3.6},
#  {'City': 'Kaitangata',
#   'Cloudiness': 54,
#   'Country': 'NZ',
#   'Date': 1569561264,
#   'Humidity': 60,
#   'Lat': -46.28,
#   'Lng': 169.85,
#   'Max Temp': 286.48,
#   'Wind Speed': 4.47},
#  {'City': 'Bambous Virieux',
#   'Cloudiness': 40,
#   'Country': 'MU',
#   'Date': 1569561264,
#   'Humidity': 73,
#   'Lat': -20.34,
#   'Lng': 57.76,
#   'Max Temp': 298.15,
#   'Wind Speed': 7.2},
#  {'City': 'Hermanus',
#   'Cloudiness': 23,
#   'Country': 'ZA',
#   'Date': 1569561264,
#   'Humidity': 48,
#   'Lat': -34.42,
#   'Lng': 19.24,
#   'Max Temp': 292.59,
#   'Wind Speed': 3.6},
#  {'City': 'Hobart',
#   'Cloudiness': 75,
#   'Country': 'AU',
#   'Date': 1569561059,
#   'Humidity': 54,
#   'Lat': -42.88,
#   'Lng': 147.33,
#   'Max Temp': 288.15,
#   'Wind Speed': 4.6},
#  {'City': 'Lorengau',
#   'Cloudiness': 11,
#   'Country': 'PG',
#   'Date': 1569561265,
#   'Humidity': 68,
#   'Lat': -2.02,
#   'Lng': 147.27,
#   'Max Temp': 302.512,
#   'Wind Speed': 4.56},
#  {'City': 'Huilong',
#   'Cloudiness': 31,
#   'Country': 'CN',
#   'Date': 1569561265,
#   'Humidity': 49,
#   'Lat': 31.15,
#   'Lng': 106.5,
#   'Max Temp': 300.452,
#   'Wind Speed': 1.2},
#  {'City': 'Paamiut',
#   'Cloudiness': 8,
#   'Country': 'GL',
#   'Date': 1569561265,
#   'Humidity': 77,
#   'Lat': 61.99,
#   'Lng': -49.67,
#   'Max Temp': 279.362,
#   'Wind Speed': 6.36},
#  {'City': 'Takoradi',
#   'Cloudiness': 90,
#   'Country': 'GH',
#   'Date': 1569561266,
#   'Humidity': 95,
#   'Lat': 4.89,
#   'Lng': -1.75,
#   'Max Temp': 296.382,
#   'Wind Speed': 1.81},
#  {'City': 'Ixtapa',
#   'Cloudiness': 90,
#   'Country': 'MX',
#   'Date': 1569561266,
#   'Humidity': 89,
#   'Lat': 20.71,
#   'Lng': -105.21,
#   'Max Temp': 302.15,
#   'Wind Speed': 1},
#  {'City': 'Mehamn',
#   'Cloudiness': 90,
#   'Country': 'NO',
#   'Date': 1569561266,
#   'Humidity': 100,
#   'Lat': 71.03,
#   'Lng': 27.85,
#   'Max Temp': 281.15,
#   'Wind Speed': 7.7},
#  {'City': 'San Patricio',
#   'Cloudiness': 0,
#   'Country': 'PY',
#   'Date': 1569561266,
#   'Humidity': 79,
#   'Lat': -26.98,
#   'Lng': -56.83,
#   'Max Temp': 287.752,
#   'Wind Speed': 2.85},
#  {'City': 'Nikologory',
#   'Cloudiness': 57,
#   'Country': 'RU',
#   'Date': 1569561267,
#   'Humidity': 85,
#   'Lat': 56.14,
#   'Lng': 41.99,
#   'Max Temp': 278.602,
#   'Wind Speed': 2.29},
#  {'City': 'Santa Vitoria do Palmar',
#   'Cloudiness': 1,
#   'Country': 'BR',
#   'Date': 1569561267,
#   'Humidity': 93,
#   'Lat': -33.52,
#   'Lng': -53.37,
#   'Max Temp': 284.432,
#   'Wind Speed': 2.93},
#  {'City': 'Jumla',
#   'Cloudiness': 100,
#   'Country': 'NP',
#   'Date': 1569561267,
#   'Humidity': 94,
#   'Lat': 29.28,
#   'Lng': 82.18,
#   'Max Temp': 284.482,
#   'Wind Speed': 1.12},
#  {'City': 'Nikolskoye',
#   'Cloudiness': 90,
#   'Country': 'RU',
#   'Date': 1569561267,
#   'Humidity': 87,
#   'Lat': 59.7,
#   'Lng': 30.79,
#   'Max Temp': 281.48,
#   'Wind Speed': 2},
#  {'City': 'Sedan',
#   'Cloudiness': 100,
#   'Country': 'FR',
#   'Date': 1569561267,
#   'Humidity': 100,
#   'Lat': 49.7,
#   'Lng': 4.94,
#   'Max Temp': 285.93,
#   'Wind Speed': 4.6},
#  {'City': 'Mar del Plata',
#   'Cloudiness': 100,
#   'Country': 'AR',
#   'Date': 1569561024,
#   'Humidity': 51,
#   'Lat': -46.43,
#   'Lng': -67.52,
#   'Max Temp': 284.262,
#   'Wind Speed': 7.83},
#  {'City': 'Waddan',
#   'Cloudiness': 0,
#   'Country': 'LY',
#   'Date': 1569561268,
#   'Humidity': 63,
#   'Lat': 29.16,
#   'Lng': 16.14,
#   'Max Temp': 296.192,
#   'Wind Speed': 1.64},
#  {'City': 'Thompson',
#   'Cloudiness': 75,
#   'Country': 'CA',
#   'Date': 1569561268,
#   'Humidity': 86,
#   'Lat': 55.74,
#   'Lng': -97.86,
#   'Max Temp': 271.15,
#   'Wind Speed': 3.38},
#  {'City': 'Broken Hill',
#   'Cloudiness': 8,
#   'Country': 'AU',
#   'Date': 1569561268,
#   'Humidity': 11,
#   'Lat': -31.97,
#   'Lng': 141.45,
#   'Max Temp': 300.15,
#   'Wind Speed': 6.2},
#  {'City': 'Solnechnyy',
#   'Cloudiness': 0,
#   'Country': 'RU',
#   'Date': 1569561268,
#   'Humidity': 64,
#   'Lat': 50.72,
#   'Lng': 136.64,
#   'Max Temp': 288.892,
#   'Wind Speed': 2.38},
#  {'City': 'Aykhal',
#   'Cloudiness': 90,
#   'Country': 'RU',
#   'Date': 1569561269,
#   'Humidity': 69,
#   'Lat': 65.95,
#   'Lng': 111.51,
#   'Max Temp': 275.15,
#   'Wind Speed': 2},
#  {'City': 'Itaituba',
#   'Cloudiness': 81,
#   'Country': 'BR',
#   'Date': 1569561269,
#   'Humidity': 82,
#   'Lat': -4.26,
#   'Lng': -55.99,
#   'Max Temp': 296.762,
#   'Wind Speed': 0.54},
#  {'City': 'Hamilton',
#   'Cloudiness': 5,
#   'Country': 'CA',
#   'Date': 1569561111,
#   'Humidity': 87,
#   'Lat': 43.26,
#   'Lng': -79.87,
#   'Max Temp': 286.48,
#   'Wind Speed': 2.1},
#  {'City': 'Chokurdakh',
#   'Cloudiness': 79,
#   'Country': 'RU',
#   'Date': 1569561269,
#   'Humidity': 72,
#   'Lat': 70.62,
#   'Lng': 147.9,
#   'Max Temp': 272.272,
#   'Wind Speed': 5.01},
#  {'City': 'Itaqui',
#   'Cloudiness': 37,
#   'Country': 'BR',
#   'Date': 1569561269,
#   'Humidity': 84,
#   'Lat': -29.13,
#   'Lng': -56.55,
#   'Max Temp': 287.922,
#   'Wind Speed': 4.22},
#  {'City': 'Oussouye',
#   'Cloudiness': 76,
#   'Country': 'SN',
#   'Date': 1569561270,
#   'Humidity': 83,
#   'Lat': 12.49,
#   'Lng': -16.54,
#   'Max Temp': 299.902,
#   'Wind Speed': 3.4},
#  {'City': 'Iranshahr',
#   'Cloudiness': 0,
#   'Country': 'IR',
#   'Date': 1569561270,
#   'Humidity': 43,
#   'Lat': 27.21,
#   'Lng': 60.69,
#   'Max Temp': 305.15,
#   'Wind Speed': 3.82},
#  {'City': 'Manta',
#   'Cloudiness': 0,
#   'Country': 'RO',
#   'Date': 1569561270,
#   'Humidity': 69,
#   'Lat': 45.1,
#   'Lng': 24.1,
#   'Max Temp': 287.462,
#   'Wind Speed': 1.05},
#  {'City': 'Ribeira Grande',
#   'Cloudiness': 0,
#   'Country': 'PT',
#   'Date': 1569561270,
#   'Humidity': 90,
#   'Lat': 38.52,
#   'Lng': -28.7,
#   'Max Temp': 295.432,
#   'Wind Speed': 5.44},
#  {'City': 'Margate',
#   'Cloudiness': 75,
#   'Country': 'AU',
#   'Date': 1569561271,
#   'Humidity': 54,
#   'Lat': -43.03,
#   'Lng': 147.26,
#   'Max Temp': 288.15,
#   'Wind Speed': 4.6},
#  {'City': 'Lusambo',
#   'Cloudiness': 100,
#   'Country': 'CD',
#   'Date': 1569561271,
#   'Humidity': 90,
#   'Lat': -4.97,
#   'Lng': 23.44,
#   'Max Temp': 295.562,
#   'Wind Speed': 1.03},
#  {'City': 'Georgetown',
#   'Cloudiness': 0,
#   'Country': 'GY',
#   'Date': 1569561271,
#   'Humidity': 94,
#   'Lat': 6.8,
#   'Lng': -58.16,
#   'Max Temp': 298.15,
#   'Wind Speed': 2.73},
#  {'City': 'Cherskiy',
#   'Cloudiness': 15,
#   'Country': 'RU',
#   'Date': 1569561271,
#   'Humidity': 56,
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 273.732,
#   'Wind Speed': 3.38},
#  {'City': 'Bom Jesus',
#   'Cloudiness': 63,
#   'Country': 'BR',
#   'Date': 1569561272,
#   'Humidity': 47,
#   'Lat': -9.08,
#   'Lng': -44.36,
#   'Max Temp': 296.402,
#   'Wind Speed': 0.62},
#  {'City': 'Lavrentiya',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1569561272,
#   'Humidity': 99,
#   'Lat': 65.58,
#   'Lng': -170.99,
#   'Max Temp': 276.612,
#   'Wind Speed': 2.25},
#  {'City': 'Port Lincoln',
#   'Cloudiness': 29,
#   'Country': 'AU',
#   'Date': 1569561272,
#   'Humidity': 72,
#   'Lat': -34.72,
#   'Lng': 135.86,
#   'Max Temp': 285.262,
#   'Wind Speed': 6.57},
#  {'City': 'Hithadhoo',
#   'Cloudiness': 84,
#   'Country': 'MV',
#   'Date': 1569561272,
#   'Humidity': 67,
#   'Lat': -0.6,
#   'Lng': 73.08,
#   'Max Temp': 301.902,
#   'Wind Speed': 4.07},
#  {'City': 'Lasa',
#   'Cloudiness': 20,
#   'Country': 'CY',
#   'Date': 1569561273,
#   'Humidity': 83,
#   'Lat': 34.92,
#   'Lng': 32.53,
#   'Max Temp': 294.15,
#   'Wind Speed': 3.1},
#  {'City': 'Gallup',
#   'Cloudiness': 75,
#   'Country': 'US',
#   'Date': 1569561273,
#   'Humidity': 55,
#   'Lat': 35.53,
#   'Lng': -108.74,
#   'Max Temp': 289.15,
#   'Wind Speed': 5.1},
#  {'City': 'Atar',
#   'Cloudiness': 0,
#   'Country': 'MR',
#   'Date': 1569561273,
#   'Humidity': 15,
#   'Lat': 20.52,
#   'Lng': -13.05,
#   'Max Temp': 304.842,
#   'Wind Speed': 1.89},
#  {'City': 'Upernavik',
#   'Cloudiness': 100,
#   'Country': 'GL',
#   'Date': 1569561274,
#   'Humidity': 55,
#   'Lat': 72.79,
#   'Lng': -56.15,
#   'Max Temp': 277.442,
#   'Wind Speed': 3.76},
#  {'City': 'Sao Filipe',
#   'Cloudiness': 59,
#   'Country': 'CV',
#   'Date': 1569561274,
#   'Humidity': 86,
#   'Lat': 14.9,
#   'Lng': -24.5,
#   'Max Temp': 298.262,
#   'Wind Speed': 6.35},
#  {'City': 'Goderich',
#   'Cloudiness': 20,
#   'Country': 'CA',
#   'Date': 1569561274,
#   'Humidity': 89,
#   'Lat': 43.74,
#   'Lng': -81.71,
#   'Max Temp': 289.82,
#   'Wind Speed': 6.11},
#  {'City': 'Shagonar',
#   'Cloudiness': 73,
#   'Country': 'RU',
#   'Date': 1569561274,
#   'Humidity': 63,
#   'Lat': 51.54,
#   'Lng': 92.92,
#   'Max Temp': 282.072,
#   'Wind Speed': 1.61},
#  {'City': 'Amambai',
#   'Cloudiness': 0,
#   'Country': 'BR',
#   'Date': 1569561275,
#   'Humidity': 63,
#   'Lat': -23.11,
#   'Lng': -55.23,
#   'Max Temp': 290.652,
#   'Wind Speed': 1.89},
#  {'City': 'Kruisfontein',
#   'Cloudiness': 0,
#   'Country': 'ZA',
#   'Date': 1569561275,
#   'Humidity': 22,
#   'Lat': -34,
#   'Lng': 24.73,
#   'Max Temp': 297.702,
#   'Wind Speed': 3.57},
#  {'City': 'Alyangula',
#   'Cloudiness': 0,
#   'Country': 'AU',
#   'Date': 1569561275,
#   'Humidity': 58,
#   'Lat': -13.85,
#   'Lng': 136.42,
#   'Max Temp': 303.15,
#   'Wind Speed': 4.6},
#  {'City': 'Lebu',
#   'Cloudiness': 15,
#   'Country': 'ET',
#   'Date': 1569561275,
#   'Humidity': 78,
#   'Lat': 8.96,
#   'Lng': 38.73,
#   'Max Temp': 289.442,
#   'Wind Speed': 1.6},
#  {'City': 'Ancud',
#   'Cloudiness': 0,
#   'Country': 'CL',
#   'Date': 1569561276,
#   'Humidity': 81,
#   'Lat': -41.87,
#   'Lng': -73.83,
#   'Max Temp': 283.15,
#   'Wind Speed': 2.1},
#  {'City': 'Arraial do Cabo',
#   'Cloudiness': 100,
#   'Country': 'BR',
#   'Date': 1569561276,
#   'Humidity': 90,
#   'Lat': -22.97,
#   'Lng': -42.02,
#   'Max Temp': 292.952,
#   'Wind Speed': 4.48},
#  {'City': 'Ocean City',
#   'Cloudiness': 75,
#   'Country': 'US',
#   'Date': 1569561277,
#   'Humidity': 83,
#   'Lat': 30.44,
#   'Lng': -86.61,
#   'Max Temp': 301.48,
#   'Wind Speed': 2.06},
#  {'City': 'Bredasdorp',
#   'Cloudiness': 21,
#   'Country': 'ZA',
#   'Date': 1569561277,
#   'Humidity': 66,
#   'Lat': -34.53,
#   'Lng': 20.04,
#   'Max Temp': 282.15,
#   'Wind Speed': 3.1},
#  {'City': 'Santa Maria',
#   'Cloudiness': 0,
#   'Country': 'BR',
#   'Date': 1569561277,
#   'Humidity': 82,
#   'Lat': -16.02,
#   'Lng': -48.01,
#   'Max Temp': 293.15,
#   'Wind Speed': 1},
#  {'City': 'Jamestown',
#   'Cloudiness': 0,
#   'Country': 'AU',
#   'Date': 1569561277,
#   'Humidity': 54,
#   'Lat': -33.21,
#   'Lng': 138.6,
#   'Max Temp': 292.702,
#   'Wind Speed': 6.56},
#  {'City': 'Rosario',
#   'Cloudiness': 64,
#   'Country': 'UY',
#   'Date': 1569561277,
#   'Humidity': 93,
#   'Lat': -34.31,
#   'Lng': -57.35,
#   'Max Temp': 283.15,
#   'Wind Speed': 1.34},
#  {'City': 'Alofi',
#   'Cloudiness': 100,
#   'Country': 'NU',
#   'Date': 1569561278,
#   'Humidity': 65,
#   'Lat': -19.06,
#   'Lng': -169.92,
#   'Max Temp': 298.15,
#   'Wind Speed': 7.7},
#  {'City': 'Marsh Harbour',
#   'Cloudiness': 13,
#   'Country': 'BS',
#   'Date': 1569561278,
#   'Humidity': 75,
#   'Lat': 26.54,
#   'Lng': -77.06,
#   'Max Temp': 299.332,
#   'Wind Speed': 5.97},
#  {'City': 'Airai',
#   'Cloudiness': 0,
#   'Country': 'TL',
#   'Date': 1569561279,
#   'Humidity': 50,
#   'Lat': -8.93,
#   'Lng': 125.41,
#   'Max Temp': 302.152,
#   'Wind Speed': 2.41},
#  {'City': 'Norman Wells',
#   'Cloudiness': 75,
#   'Country': 'CA',
#   'Date': 1569561279,
#   'Humidity': 74,
#   'Lat': 65.28,
#   'Lng': -126.83,
#   'Max Temp': 274.15,
#   'Wind Speed': 1.5},
#  {'City': 'Provideniya',
#   'Cloudiness': 90,
#   'Country': 'RU',
#   'Date': 1569561279,
#   'Humidity': 87,
#   'Lat': 64.42,
#   'Lng': -173.23,
#   'Max Temp': 282.15,
#   'Wind Speed': 6},
#  {'City': 'Springdale',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1569561279,
#   'Humidity': 94,
#   'Lat': 36.19,
#   'Lng': -94.13,
#   'Max Temp': 294.15,
#   'Wind Speed': 3.6},
#  {'City': 'San Felipe',
#   'Cloudiness': 45,
#   'Country': 'CL',
#   'Date': 1569561280,
#   'Humidity': 99,
#   'Lat': -32.75,
#   'Lng': -70.73,
#   'Max Temp': 283.71,
#   'Wind Speed': 1.74},
#  {'City': 'Gazanjyk',
#   'Cloudiness': 0,
#   'Country': 'TM',
#   'Date': 1569561280,
#   'Humidity': 50,
#   'Lat': 39.24,
#   'Lng': 55.52,
#   'Max Temp': 297.382,
#   'Wind Speed': 3.31},
#  {'City': 'Florianopolis',
#   'Cloudiness': 40,
#   'Country': 'BR',
#   'Date': 1569561250,
#   'Humidity': 93,
#   'Lat': -27.6,
#   'Lng': -48.55,
#   'Max Temp': 293.15,
#   'Wind Speed': 2.1},
#  {'City': 'Saint-Augustin',
#   'Cloudiness': 5,
#   'Country': 'CA',
#   'Date': 1569561280,
#   'Humidity': 100,
#   'Lat': 45.63,
#   'Lng': -73.98,
#   'Max Temp': 285.37,
#   'Wind Speed': 1},
#  {'City': 'Azuaga',
#   'Cloudiness': 0,
#   'Country': 'ES',
#   'Date': 1569561281,
#   'Humidity': 57,
#   'Lat': 38.26,
#   'Lng': -5.68,
#   'Max Temp': 290.37,
#   'Wind Speed': 2.24},
#  {'City': 'Severo-Kurilsk',
#   'Cloudiness': 64,
#   'Country': 'RU',
#   'Date': 1569561281,
#   'Humidity': 80,
#   'Lat': 50.68,
#   'Lng': 156.12,
#   'Max Temp': 280.992,
#   'Wind Speed': 12.34},
#  {'City': 'Iqaluit',
#   'Cloudiness': 75,
#   'Country': 'CA',
#   'Date': 1569561281,
#   'Humidity': 86,
#   'Lat': 63.75,
#   'Lng': -68.52,
#   'Max Temp': 276.15,
#   'Wind Speed': 10.8},
#  {'City': 'Ostrovnoy',
#   'Cloudiness': 98,
#   'Country': 'RU',
#   'Date': 1569561281,
#   'Humidity': 83,
#   'Lat': 68.05,
#   'Lng': 39.51,
#   'Max Temp': 276.892,
#   'Wind Speed': 4.95},
#  {'City': 'Bethel',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': 1569561281,
#   'Humidity': 76,
#   'Lat': 60.79,
#   'Lng': -161.76,
#   'Max Temp': 283.15,
#   'Wind Speed': 6.2},
#  {'City': 'Nguruka',
#   'Cloudiness': 92,
#   'Country': 'TZ',
#   'Date': 1569561282,
#   'Humidity': 50,
#   'Lat': -5.11,
#   'Lng': 31.04,
#   'Max Temp': 296.602,
#   'Wind Speed': 4.97},
#  {'City': 'Vardo',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1569561282,
#   'Humidity': 93,
#   'Lat': 39.62,
#   'Lng': -77.74,
#   'Max Temp': 290.37,
#   'Wind Speed': 1.08},
#  {'City': 'Viedma',
#   'Cloudiness': 83,
#   'Country': 'AR',
#   'Date': 1569561282,
#   'Humidity': 61,
#   'Lat': -40.81,
#   'Lng': -62.99,
#   'Max Temp': 281.092,
#   'Wind Speed': 6.87},
#  {'City': 'Almaznyy',
#   'Cloudiness': 75,
#   'Country': 'RU',
#   'Date': 1569561282,
#   'Humidity': 93,
#   'Lat': 48.03,
#   'Lng': 40.04,
#   'Max Temp': 283.15,
#   'Wind Speed': 4},
#  {'City': 'Talas',
#   'Cloudiness': 41,
#   'Country': 'KG',
#   'Date': 1569561283,
#   'Humidity': 90,
#   'Lat': 42.52,
#   'Lng': 72.24,
#   'Max Temp': 283.71,
#   'Wind Speed': 1.84},
#  {'City': 'Chinsali',
#   'Cloudiness': 91,
#   'Country': 'ZM',
#   'Date': 1569561283,
#   'Humidity': 50,
#   'Lat': -10.55,
#   'Lng': 32.07,
#   'Max Temp': 290.552,
#   'Wind Speed': 4.83},
#  {'City': 'Katobu',
#   'Cloudiness': 73,
#   'Country': 'ID',
#   'Date': 1569561283,
#   'Humidity': 43,
#   'Lat': -4.94,
#   'Lng': 122.53,
#   'Max Temp': 305.632,
#   'Wind Speed': 1.49},
#  {'City': 'Pisco',
#   'Cloudiness': 13,
#   'Country': 'PE',
#   'Date': 1569561283,
#   'Humidity': 87,
#   'Lat': -13.71,
#   'Lng': -76.2,
#   'Max Temp': 289.26,
#   'Wind Speed': 2.1},
#  {'City': 'Tezu',
#   'Cloudiness': 0,
#   'Country': 'IN',
#   'Date': 1569561284,
#   'Humidity': 54,
#   'Lat': 27.93,
#   'Lng': 96.16,
#   'Max Temp': 302.712,
#   'Wind Speed': 1.58},
#  {'City': 'Ust-Nera',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1569561284,
#   'Humidity': 73,
#   'Lat': 64.57,
#   'Lng': 143.24,
#   'Max Temp': 271.882,
#   'Wind Speed': 3.19},
#  {'City': 'Broome',
#   'Cloudiness': 32,
#   'Country': 'GB',
#   'Date': 1569561284,
#   'Humidity': 93,
#   'Lat': 52.47,
#   'Lng': 1.45,
#   'Max Temp': 287.59,
#   'Wind Speed': 4.1},
#  {'City': 'Alice Springs',
#   'Cloudiness': 0,
#   'Country': 'AU',
#   'Date': 1569561284,
#   'Humidity': 19,
#   'Lat': -23.7,
#   'Lng': 133.88,
#   'Max Temp': 303.15,
#   'Wind Speed': 3.1},
#  {'City': 'Raton',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1569561285,
#   'Humidity': 36,
#   'Lat': 36.9,
#   'Lng': -104.44,
#   'Max Temp': 293.15,
#   'Wind Speed': 3.6},
#  {'City': 'Finschhafen',
#   'Cloudiness': 100,
#   'Country': 'PG',
#   'Date': 1569561285,
#   'Humidity': 94,
#   'Lat': -6.6,
#   'Lng': 147.85,
#   'Max Temp': 294.322,
#   'Wind Speed': 1.05},
#  {'City': 'Yellowknife',
#   'Cloudiness': 40,
#   'Country': 'CA',
#   'Date': 1569561285,
#   'Humidity': 75,
#   'Lat': 62.45,
#   'Lng': -114.38,
#   'Max Temp': 273.15,
#   'Wind Speed': 2.1},
#  {'City': 'Buraydah',
#   'Cloudiness': 0,
#   'Country': 'SA',
#   'Date': 1569561285,
#   'Humidity': 38,
#   'Lat': 26.33,
#   'Lng': 43.97,
#   'Max Temp': 297.15,
#   'Wind Speed': 1},
#  {'City': 'Geraldton',
#   'Cloudiness': 90,
#   'Country': 'CA',
#   'Date': 1569561286,
#   'Humidity': 81,
#   'Lat': 49.72,
#   'Lng': -86.95,
#   'Max Temp': 282.15,
#   'Wind Speed': 3.1},
#  {'City': 'Kodiak',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': 1569561286,
#   'Humidity': 60,
#   'Lat': 39.95,
#   'Lng': -94.76,
#   'Max Temp': 294.26,
#   'Wind Speed': 5.1},
#  {'City': 'Mananjary',
#   'Cloudiness': 21,
#   'Country': 'MG',
#   'Date': 1569561286,
#   'Humidity': 45,
#   'Lat': -19.16,
#   'Lng': 46.8,
#   'Max Temp': 295.752,
#   'Wind Speed': 5.96},
#  {'City': 'Boende',
#   'Cloudiness': 89,
#   'Country': 'CD',
#   'Date': 1569561286,
#   'Humidity': 80,
#   'Lat': -0.28,
#   'Lng': 20.88,
#   'Max Temp': 297.212,
#   'Wind Speed': 1.06},
#  {'City': 'Salcioara',
#   'Cloudiness': 0,
#   'Country': 'RO',
#   'Date': 1569561286,
#   'Humidity': 100,
#   'Lat': 44.72,
#   'Lng': 25.58,
#   'Max Temp': 290.37,
#   'Wind Speed': 1},
#  {'City': 'Richards Bay',
#   'Cloudiness': 0,
#   'Country': 'ZA',
#   'Date': 1569561287,
#   'Humidity': 69,
#   'Lat': -28.77,
#   'Lng': 32.06,
#   'Max Temp': 290.542,
#   'Wind Speed': 7.57},
#  {'City': 'Irituia',
#   'Cloudiness': 20,
#   'Country': 'BR',
#   'Date': 1569561287,
#   'Humidity': 98,
#   'Lat': -1.77,
#   'Lng': -47.44,
#   'Max Temp': 295.012,
#   'Wind Speed': 1.7},
#  {'City': 'Cache Creek',
#   'Cloudiness': 40,
#   'Country': 'CA',
#   'Date': 1569561287,
#   'Humidity': 53,
#   'Lat': 50.81,
#   'Lng': -121.33,
#   'Max Temp': 286.15,
#   'Wind Speed': 2.6},
#  {'City': 'Kajaani',
#   'Cloudiness': 90,
#   'Country': 'FI',
#   'Date': 1569561043,
#   'Humidity': 93,
#   'Lat': 64.22,
#   'Lng': 27.73,
#   'Max Temp': 281.15,
#   'Wind Speed': 1.5},
#  {'City': 'Awjilah',
#   'Cloudiness': 0,
#   'Country': 'LY',
#   'Date': 1569561287,
#   'Humidity': 51,
#   'Lat': 29.14,
#   'Lng': 21.3,
#   'Max Temp': 296.272,
#   'Wind Speed': 0.83},
#  {'City': 'Saldanha',
#   'Cloudiness': 23,
#   'Country': 'PT',
#   'Date': 1569561288,
#   'Humidity': 83,
#   'Lat': 41.42,
#   'Lng': -6.55,
#   'Max Temp': 284.802,
#   'Wind Speed': 0.89},
#  {'City': 'Ambilobe',
#   'Cloudiness': 55,
#   'Country': 'MG',
#   'Date': 1569561288,
#   'Humidity': 40,
#   'Lat': -13.19,
#   'Lng': 49.05,
#   'Max Temp': 303.542,
#   'Wind Speed': 1.51},
#  {'City': 'Maceio',
#   'Cloudiness': 20,
#   'Country': 'BR',
#   'Date': 1569561288,
#   'Humidity': 94,
#   'Lat': -9.67,
#   'Lng': -35.74,
#   'Max Temp': 293.15,
#   'Wind Speed': 2.1},
#  {'City': 'Skibbereen',
#   'Cloudiness': 75,
#   'Country': 'IE',
#   'Date': 1569561288,
#   'Humidity': 93,
#   'Lat': 51.55,
#   'Lng': -9.27,
#   'Max Temp': 285.15,
#   'Wind Speed': 8.2},
#  {'City': 'Mount Vernon',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1569561209,
#   'Humidity': 93,
#   'Lat': 38.73,
#   'Lng': -77.1,
#   'Max Temp': 293.15,
#   'Wind Speed': 2.38},
#  {'City': 'Yarke Pole',
#   'Cloudiness': 84,
#   'Country': 'UA',
#   'Date': 1569561289,
#   'Humidity': 78,
#   'Lat': 45.61,
#   'Lng': 34.32,
#   'Max Temp': 285.682,
#   'Wind Speed': 1.64},
#  {'City': 'Half Moon Bay',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': 1569561289,
#   'Humidity': 88,
#   'Lat': 37.46,
#   'Lng': -122.43,
#   'Max Temp': 293.15,
#   'Wind Speed': 5.1},
#  {'City': 'Necochea',
#   'Cloudiness': 61,
#   'Country': 'AR',
#   'Date': 1569561289,
#   'Humidity': 94,
#   'Lat': -38.55,
#   'Lng': -58.74,
#   'Max Temp': 277.59,
#   'Wind Speed': 0.45},
#  {'City': 'Inirida',
#   'Cloudiness': 40,
#   'Country': 'CO',
#   'Date': 1569561289,
#   'Humidity': 94,
#   'Lat': 3.87,
#   'Lng': -67.92,
#   'Max Temp': 295.982,
#   'Wind Speed': 0.81},
#  {'City': 'Makkaveyevo',
#   'Cloudiness': 44,
#   'Country': 'RU',
#   'Date': 1569561290,
#   'Humidity': 37,
#   'Lat': 51.75,
#   'Lng': 113.95,
#   'Max Temp': 293.15,
#   'Wind Speed': 1.75},
#  {'City': 'Kumbhraj',
#   'Cloudiness': 100,
#   'Country': 'IN',
#   'Date': 1569561290,
#   'Humidity': 80,
#   'Lat': 24.44,
#   'Lng': 77,
#   'Max Temp': 299.522,
#   'Wind Speed': 3.92},
#  {'City': 'Lewistown',
#   'Cloudiness': 75,
#   'Country': 'US',
#   'Date': 1569561290,
#   'Humidity': 71,
#   'Lat': 40.39,
#   'Lng': -90.15,
#   'Max Temp': 289.82,
#   'Wind Speed': 2.1},
#  {'City': 'Chipinge',
#   'Cloudiness': 12,
#   'Country': 'ZW',
#   'Date': 1569561290,
#   'Humidity': 64,
#   'Lat': -20.19,
#   'Lng': 32.62,
#   'Max Temp': 287.622,
#   'Wind Speed': 1.68},
#  {'City': 'Zaysan',
#   'Cloudiness': 100,
#   'Country': 'KZ',
#   'Date': 1569561291,
#   'Humidity': 36,
#   'Lat': 47.47,
#   'Lng': 84.87,
#   'Max Temp': 289.172,
#   'Wind Speed': 3.09},
#  {'City': 'Port Macquarie',
#   'Cloudiness': 60,
#   'Country': 'AU',
#   'Date': 1569561291,
#   'Humidity': 46,
#   'Lat': -31.43,
#   'Lng': 152.91,
#   'Max Temp': 298.15,
#   'Wind Speed': 5.7},
#  {'City': 'Pacific Grove',
#   'Cloudiness': 75,
#   'Country': 'US',
#   'Date': 1569561181,
#   'Humidity': 77,
#   'Lat': 36.62,
#   'Lng': -121.92,
#   'Max Temp': 293.15,
#   'Wind Speed': 5.7},
#  {'City': 'Mwinilunga',
#   'Cloudiness': 60,
#   'Country': 'ZM',
#   'Date': 1569561291,
#   'Humidity': 48,
#   'Lat': -11.73,
#   'Lng': 24.43,
#   'Max Temp': 289.452,
#   'Wind Speed': 5.28},
#  {'City': 'Taoudenni',
#   'Cloudiness': 0,
#   'Country': 'ML',
#   'Date': 1569561292,
#   'Humidity': 13,
#   'Lat': 22.68,
#   'Lng': -3.98,
#   'Max Temp': 304.802,
#   'Wind Speed': 2.34},
#  {'City': 'Adrar',
#   'Cloudiness': 0,
#   'Country': 'DZ',
#   'Date': 1569561292,
#   'Humidity': 11,
#   'Lat': 27.87,
#   'Lng': -0.29,
#   'Max Temp': 300.15,
#   'Wind Speed': 2.6},
#  {'City': 'Port Augusta',
#   'Cloudiness': 0,
#   'Country': 'AU',
#   'Date': 1569561292,
#   'Humidity': 67,
#   'Lat': -32.49,
#   'Lng': 137.76,
#   'Max Temp': 300.37,
#   'Wind Speed': 8.7},
#  {'City': 'Fernandez',
#   'Cloudiness': 0,
#   'Country': 'AR',
#   'Date': 1569561292,
#   'Humidity': 74,
#   'Lat': -51.64,
#   'Lng': -69.22,
#   'Max Temp': 274.15,
#   'Wind Speed': 1},
#  {'City': 'Dubbo',
#   'Cloudiness': 96,
#   'Country': 'AU',
#   'Date': 1569561293,
#   'Humidity': 14,
#   'Lat': -32.25,
#   'Lng': 148.6,
#   'Max Temp': 297.15,
#   'Wind Speed': 6.2},
#  {'City': 'Jutai',
#   'Cloudiness': 0,
#   'Country': 'BR',
#   'Date': 1569561293,
#   'Humidity': 98,
#   'Lat': -1.71,
#   'Lng': -47.89,
#   'Max Temp': 295.572,
#   'Wind Speed': 1.17},
#  {'City': 'Konin',
#   'Cloudiness': 0,
#   'Country': 'PL',
#   'Date': 1569561293,
#   'Humidity': 92,
#   'Lat': 52.23,
#   'Lng': 18.25,
#   'Max Temp': 282.04,
#   'Wind Speed': 3.27},
#  {'City': 'Saint-Philippe',
#   'Cloudiness': 1,
#   'Country': 'CA',
#   'Date': 1569561293,
#   'Humidity': 93,
#   'Lat': 45.36,
#   'Lng': -73.48,
#   'Max Temp': 285.37,
#   'Wind Speed': 3.38},
#  {'City': 'Emerald',
#   'Cloudiness': 10,
#   'Country': 'AU',
#   'Date': 1569561294,
#   'Humidity': 28,
#   'Lat': -23.53,
#   'Lng': 148.16,
#   'Max Temp': 303.15,
#   'Wind Speed': 2.6},
#  {'City': 'Victoria',
#   'Cloudiness': 75,
#   'Country': 'BN',
#   'Date': 1569561252,
#   'Humidity': 70,
#   'Lat': 5.28,
#   'Lng': 115.24,
#   'Max Temp': 305.15,
#   'Wind Speed': 2.6},
#  {'City': 'Lexington',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1569561114,
#   'Humidity': 54,
#   'Lat': 38.05,
#   'Lng': -84.5,
#   'Max Temp': 290.15,
#   'Wind Speed': 1.5},
#  {'City': 'Vestmannaeyjar',
#   'Cloudiness': 100,
#   'Country': 'IS',
#   'Date': 1569561294,
#   'Humidity': 91,
#   'Lat': 63.44,
#   'Lng': -20.27,
#   'Max Temp': 283.102,
#   'Wind Speed': 1.98},
#  {'City': 'Thunder Bay',
#   'Cloudiness': 90,
#   'Country': 'CA',
#   'Date': 1569561228,
#   'Humidity': 71,
#   'Lat': 48.41,
#   'Lng': -89.26,
#   'Max Temp': 286.48,
#   'Wind Speed': 1.5},
#  {'City': 'Sandpoint',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': 1569561295,
#   'Humidity': 81,
#   'Lat': 48.28,
#   'Lng': -116.55,
#   'Max Temp': 285.15,
#   'Wind Speed': 1.8},
#  {'City': 'Kavaratti',
#   'Cloudiness': 75,
#   'Country': 'IN',
#   'Date': 1569561295,
#   'Humidity': 79,
#   'Lat': 10.57,
#   'Lng': 72.64,
#   'Max Temp': 302.15,
#   'Wind Speed': 2.1},
#  {'City': 'Muros',
#   'Cloudiness': 90,
#   'Country': 'ES',
#   'Date': 1569561295,
#   'Humidity': 100,
#   'Lat': 42.77,
#   'Lng': -9.06,
#   'Max Temp': 292.04,
#   'Wind Speed': 3.1},
#  {'City': 'Luderitz',
#   'Cloudiness': 92,
#   'Country': 'NA',
#   'Date': 1569561295,
#   'Humidity': 27,
#   'Lat': -26.65,
#   'Lng': 15.16,
#   'Max Temp': 304.15,
#   'Wind Speed': 9.8},
#  {'City': 'Nanortalik',
#   'Cloudiness': 0,
#   'Country': 'GL',
#   'Date': 1569561296,
#   'Humidity': 79,
#   'Lat': 60.14,
#   'Lng': -45.24,
#   'Max Temp': 278.552,
#   'Wind Speed': 2.9},
#  {'City': 'Vila Franca do Campo',
#   'Cloudiness': 20,
#   'Country': 'PT',
#   'Date': 1569561296,
#   'Humidity': 94,
#   'Lat': 37.72,
#   'Lng': -25.43,
#   'Max Temp': 295.15,
#   'Wind Speed': 5.1},
#  {'City': 'Cao Bang',
#   'Cloudiness': 0,
#   'Country': 'VN',
#   'Date': 1569561296,
#   'Humidity': 35,
#   'Lat': 22.67,
#   'Lng': 106.25,
#   'Max Temp': 301.752,
#   'Wind Speed': 1.56},
#  {'City': 'Sint-Genesius-Rode',
#   'Cloudiness': 40,
#   'Country': 'BE',
#   'Date': 1569561296,
#   'Humidity': 93,
#   'Lat': 50.74,
#   'Lng': 4.35,
#   'Max Temp': 287.59,
#   'Wind Speed': 4.6},
#  {'City': 'Fairbanks',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': 1569561234,
#   'Humidity': 93,
#   'Lat': 64.84,
#   'Lng': -147.72,
#   'Max Temp': 276.15,
#   'Wind Speed': 1.29},
#  {'City': 'Dhidhdhoo',
#   'Cloudiness': 100,
#   'Country': 'MV',
#   'Date': 1569561297,
#   'Humidity': 68,
#   'Lat': 6.88,
#   'Lng': 73.1,
#   'Max Temp': 301.442,
#   'Wind Speed': 2.47},
#  {'City': 'Kirakira',
#   'Cloudiness': 66,
#   'Country': 'SB',
#   'Date': 1569561297,
#   'Humidity': 77,
#   'Lat': -10.46,
#   'Lng': 161.92,
#   'Max Temp': 301.102,
#   'Wind Speed': 1.55},
#  {'City': 'Yar-Sale',
#   'Cloudiness': 71,
#   'Country': 'RU',
#   'Date': 1569561297,
#   'Humidity': 91,
#   'Lat': 66.83,
#   'Lng': 70.83,
#   'Max Temp': 275.232,
#   'Wind Speed': 2.57},
#  {'City': 'Mapimi',
#   'Cloudiness': 40,
#   'Country': 'MX',
#   'Date': 1569561297,
#   'Humidity': 48,
#   'Lat': 25.82,
#   'Lng': -103.85,
#   'Max Temp': 301.15,
#   'Wind Speed': 3.66},
#  {'City': 'Sorland',
#   'Cloudiness': 0,
#   'Country': 'NO',
#   'Date': 1569561298,
#   'Humidity': 87,
#   'Lat': 67.67,
#   'Lng': 12.69,
#   'Max Temp': 281.15,
#   'Wind Speed': 1},
#  {'City': 'Souillac',
#   'Cloudiness': 75,
#   'Country': 'FR',
#   'Date': 1569561298,
#   'Humidity': 93,
#   'Lat': 45.6,
#   'Lng': -0.6,
#   'Max Temp': 290.37,
#   'Wind Speed': 5.7},
#  {'City': 'Prince Rupert',
#   'Cloudiness': 90,
#   'Country': 'CA',
#   'Date': 1569561298,
#   'Humidity': 87,
#   'Lat': 54.32,
#   'Lng': -130.32,
#   'Max Temp': 281.15,
#   'Wind Speed': 1.5},
#  {'City': 'Chuy',
#   'Cloudiness': 0,
#   'Country': 'UY',
#   'Date': 1569561187,
#   'Humidity': 90,
#   'Lat': -33.69,
#   'Lng': -53.46,
#   'Max Temp': 286.252,
#   'Wind Speed': 3.87},
#  {'City': 'Moose Factory',
#   'Cloudiness': 1,
#   'Country': 'CA',
#   'Date': 1569561298,
#   'Humidity': 81,
#   'Lat': 51.26,
#   'Lng': -80.61,
#   'Max Temp': 281.15,
#   'Wind Speed': 5.1},
#  {'City': 'Beringovskiy',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1569561299,
#   'Humidity': 99,
#   'Lat': 63.05,
#   'Lng': 179.32,
#   'Max Temp': 278.862,
#   'Wind Speed': 3.12},
#  {'City': 'Eqbaliyeh',
#   'Cloudiness': 0,
#   'Country': 'IR',
#   'Date': 1569561299,
#   'Humidity': 17,
#   'Lat': 35.3,
#   'Lng': 51.54,
#   'Max Temp': 302.15,
#   'Wind Speed': 3.1},
#  {'City': 'Vostok',
#   'Cloudiness': 0,
#   'Country': 'RU',
#   'Date': 1569561299,
#   'Humidity': 51,
#   'Lat': 46.45,
#   'Lng': 135.83,
#   'Max Temp': 292.362,
#   'Wind Speed': 2.14},
#  {'City': 'Caravelas',
#   'Cloudiness': 26,
#   'Country': 'BR',
#   'Date': 1569561300,
#   'Humidity': 85,
#   'Lat': -17.73,
#   'Lng': -39.27,
#   'Max Temp': 295.822,
#   'Wind Speed': 3.59},
#  {'City': 'Anadyr',
#   'Cloudiness': 75,
#   'Country': 'RU',
#   'Date': 1569561300,
#   'Humidity': 93,
#   'Lat': 64.73,
#   'Lng': 177.51,
#   'Max Temp': 280.15,
#   'Wind Speed': 6},
#  {'City': 'Zima',
#   'Cloudiness': 70,
#   'Country': 'RU',
#   'Date': 1569561300,
#   'Humidity': 45,
#   'Lat': 53.93,
#   'Lng': 102.05,
#   'Max Temp': 281.052,
#   'Wind Speed': 3.13},
#  {'City': 'Ponta Delgada',
#   'Cloudiness': 20,
#   'Country': 'PT',
#   'Date': 1569561300,
#   'Humidity': 94,
#   'Lat': 37.73,
#   'Lng': -25.67,
#   'Max Temp': 295.15,
#   'Wind Speed': 5.1},
#  {'City': 'Karratha',
#   'Cloudiness': 0,
#   'Country': 'AU',
#   'Date': 1569561301,
#   'Humidity': 16,
#   'Lat': -20.74,
#   'Lng': 116.85,
#   'Max Temp': 304.312,
#   'Wind Speed': 7.8},
#  {'City': 'Namatanai',
#   'Cloudiness': 15,
#   'Country': 'PG',
#   'Date': 1569561301,
#   'Humidity': 72,
#   'Lat': -3.66,
#   'Lng': 152.44,
#   'Max Temp': 301.432,
#   'Wind Speed': 5.46},
#  {'City': 'Muhos',
#   'Cloudiness': 0,
#   'Country': 'FI',
#   'Date': 1569561301,
#   'Humidity': 93,
#   'Lat': 64.81,
#   'Lng': 26,
#   'Max Temp': 282.15,
#   'Wind Speed': 2.1},
#  {'City': 'Saskylakh',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1569561302,
#   'Humidity': 85,
#   'Lat': 71.97,
#   'Lng': 114.09,
#   'Max Temp': 274.272,
#   'Wind Speed': 3.89},
#  {'City': 'Columbus',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1569561243,
#   'Humidity': 78,
#   'Lat': 32.46,
#   'Lng': -84.99,
#   'Max Temp': 301.15,
#   'Wind Speed': 1.02},
#  {'City': 'Loreto',
#   'Cloudiness': 0,
#   'Country': 'PY',
#   'Date': 1569561303,
#   'Humidity': 50,
#   'Lat': -23.27,
#   'Lng': -57.32,
#   'Max Temp': 290.672,
#   'Wind Speed': 2.14},
#  {'City': 'East London',
#   'Cloudiness': 0,
#   'Country': 'ZA',
#   'Date': 1569561303,
#   'Humidity': 58,
#   'Lat': -33.02,
#   'Lng': 27.91,
#   'Max Temp': 287.15,
#   'Wind Speed': 2.1},
#  {'City': 'Los Llanos de Aridane',
#   'Cloudiness': 75,
#   'Country': 'ES',
#   'Date': 1569561304,
#   'Humidity': 68,
#   'Lat': 28.66,
#   'Lng': -17.92,
#   'Max Temp': 295.15,
#   'Wind Speed': 4.1},
#  {'City': 'Marienburg',
#   'Cloudiness': 75,
#   'Country': 'DE',
#   'Date': 1569561305,
#   'Humidity': 93,
#   'Lat': 52.12,
#   'Lng': 9.98,
#   'Max Temp': 288.71,
#   'Wind Speed': 2.6},
#  {'City': 'Koumac',
#   'Cloudiness': 78,
#   'Country': 'NC',
#   'Date': 1569561305,
#   'Humidity': 79,
#   'Lat': -20.56,
#   'Lng': 164.28,
#   'Max Temp': 294.912,
#   'Wind Speed': 6.56},
#  {'City': 'Sinazongwe',
#   'Cloudiness': 0,
#   'Country': 'ZM',
#   'Date': 1569561305,
#   'Humidity': 44,
#   'Lat': -17.26,
#   'Lng': 27.46,
#   'Max Temp': 288.642,
#   'Wind Speed': 1.92},
#  {'City': 'Saint-Pierre',
#   'Cloudiness': 100,
#   'Country': 'FR',
#   'Date': 1569561306,
#   'Humidity': 93,
#   'Lat': 48.95,
#   'Lng': 4.24,
#   'Max Temp': 287.59,
#   'Wind Speed': 5.1},
#  {'City': 'Torbay',
#   'Cloudiness': 90,
#   'Country': 'CA',
#   'Date': 1569561306,
#   'Humidity': 100,
#   'Lat': 47.66,
#   'Lng': -52.73,
#   'Max Temp': 283.71,
#   'Wind Speed': 6.7},
#  {'City': 'Tommot',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1569561306,
#   'Humidity': 67,
#   'Lat': 58.97,
#   'Lng': 126.27,
#   'Max Temp': 282.772,
#   'Wind Speed': 2.27},
#  {'City': 'Acapulco',
#   'Cloudiness': 90,
#   'Country': 'MX',
#   'Date': 1569561306,
#   'Humidity': 88,
#   'Lat': 16.86,
#   'Lng': -99.88,
#   'Max Temp': 301.15,
#   'Wind Speed': 1.06},
#  {'City': 'Pocone',
#   'Cloudiness': 99,
#   'Country': 'BR',
#   'Date': 1569561307,
#   'Humidity': 79,
#   'Lat': -16.26,
#   'Lng': -56.62,
#   'Max Temp': 296.672,
#   'Wind Speed': 0.92},
#  {'City': 'Nemuro',
#   'Cloudiness': 20,
#   'Country': 'JP',
#   'Date': 1569561307,
#   'Humidity': 56,
#   'Lat': 43.32,
#   'Lng': 145.57,
#   'Max Temp': 294.15,
#   'Wind Speed': 2.6},
#  {'City': 'Dingle',
#   'Cloudiness': 66,
#   'Country': 'PH',
#   'Date': 1569561307,
#   'Humidity': 61,
#   'Lat': 11,
#   'Lng': 122.67,
#   'Max Temp': 304.592,
#   'Wind Speed': 1.43},
#  {'City': 'Cooma',
#   'Cloudiness': 98,
#   'Country': 'AU',
#   'Date': 1569561308,
#   'Humidity': 33,
#   'Lat': -36.24,
#   'Lng': 149.13,
#   'Max Temp': 288.15,
#   'Wind Speed': 7.7},
#  {'City': 'Hasaki',
#   'Cloudiness': 75,
#   'Country': 'JP',
#   'Date': 1569561308,
#   'Humidity': 65,
#   'Lat': 35.73,
#   'Lng': 140.83,
#   'Max Temp': 303.15,
#   'Wind Speed': 3.1},
#  {'City': 'Ilulissat',
#   'Cloudiness': 1,
#   'Country': 'GL',
#   'Date': 1569561308,
#   'Humidity': 38,
#   'Lat': 69.22,
#   'Lng': -51.1,
#   'Max Temp': 277.15,
#   'Wind Speed': 11.3},
#  {'City': 'Doha',
#   'Cloudiness': 0,
#   'Country': 'QA',
#   'Date': 1569561309,
#   'Humidity': 75,
#   'Lat': 25.29,
#   'Lng': 51.53,
#   'Max Temp': 306.15,
#   'Wind Speed': 2.6},
#  {'City': 'Cadillac',
#   'Cloudiness': 75,
#   'Country': 'US',
#   'Date': 1569561309,
#   'Humidity': 66,
#   'Lat': 44.25,
#   'Lng': -85.4,
#   'Max Temp': 286.48,
#   'Wind Speed': 2.6},
#  {'City': 'Nalut',
#   'Cloudiness': 0,
#   'Country': 'LY',
#   'Date': 1569561309,
#   'Humidity': 75,
#   'Lat': 31.86,
#   'Lng': 10.98,
#   'Max Temp': 293.232,
#   'Wind Speed': 4.18},
#  {'City': 'Astana',
#   'Cloudiness': 90,
#   'Country': 'KZ',
#   'Date': 1569561309,
#   'Humidity': 93,
#   'Lat': 51.13,
#   'Lng': 71.43,
#   'Max Temp': 281.15,
#   'Wind Speed': 2},
#  {'City': 'Hay River',
#   'Cloudiness': 75,
#   'Country': 'CA',
#   'Date': 1569561310,
#   'Humidity': 69,
#   'Lat': 60.82,
#   'Lng': -115.79,
#   'Max Temp': 277.15,
#   'Wind Speed': 3.6},
#  {'City': 'Riyadh',
#   'Cloudiness': 15,
#   'Country': 'SA',
#   'Date': 1569561311,
#   'Humidity': 45,
#   'Lat': 24.63,
#   'Lng': 46.72,
#   'Max Temp': 302.15,
#   'Wind Speed': 1},
#  {'City': 'Wairoa',
#   'Cloudiness': 72,
#   'Country': 'NZ',
#   'Date': 1569561311,
#   'Humidity': 68,
#   'Lat': -39.04,
#   'Lng': 177.43,
#   'Max Temp': 286.48,
#   'Wind Speed': 0.45},
#  {'City': 'Lompoc',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': 1569561311,
#   'Humidity': 93,
#   'Lat': 34.64,
#   'Lng': -120.46,
#   'Max Temp': 294.15,
#   'Wind Speed': 2.6},
#  {'City': 'Osakarovka',
#   'Cloudiness': 100,
#   'Country': 'KZ',
#   'Date': 1569561312,
#   'Humidity': 87,
#   'Lat': 50.56,
#   'Lng': 72.58,
#   'Max Temp': 283.562,
#   'Wind Speed': 8.38},
#  {'City': 'Tuktoyaktuk',
#   'Cloudiness': 75,
#   'Country': 'CA',
#   'Date': 1569561312,
#   'Humidity': 81,
#   'Lat': 69.44,
#   'Lng': -133.03,
#   'Max Temp': 276.15,
#   'Wind Speed': 7.7},
#  {'City': 'San Quintin',
#   'Cloudiness': 0,
#   'Country': 'PH',
#   'Date': 1569561312,
#   'Humidity': 69,
#   'Lat': 17.54,
#   'Lng': 120.52,
#   'Max Temp': 302.582,
#   'Wind Speed': 3.08},
#  {'City': 'Portland',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1569561168,
#   'Humidity': 93,
#   'Lat': 43.66,
#   'Lng': -70.25,
#   'Max Temp': 286.48,
#   'Wind Speed': 2.1},
#  {'City': 'Kalmunai',
#   'Cloudiness': 72,
#   'Country': 'LK',
#   'Date': 1569561312,
#   'Humidity': 56,
#   'Lat': 7.42,
#   'Lng': 81.82,
#   'Max Temp': 304.592,
#   'Wind Speed': 2.82},
#  {'City': 'Colac',
#   'Cloudiness': 70,
#   'Country': 'AU',
#   'Date': 1569561313,
#   'Humidity': 75,
#   'Lat': -38.34,
#   'Lng': 143.59,
#   'Max Temp': 285.37,
#   'Wind Speed': 2.68},
#  {'City': 'Flinders',
#   'Cloudiness': 0,
#   'Country': 'AU',
#   'Date': 1569561314,
#   'Humidity': 48,
#   'Lat': -34.58,
#   'Lng': 150.85,
#   'Max Temp': 297.15,
#   'Wind Speed': 6.2},
#  {'City': 'Bambanglipuro',
#   'Cloudiness': 9,
#   'Country': 'ID',
#   'Date': 1569561314,
#   'Humidity': 83,
#   'Lat': -7.95,
#   'Lng': 110.28,
#   'Max Temp': 297.752,
#   'Wind Speed': 6.93},
#  {'City': 'Great Falls',
#   'Cloudiness': 75,
#   'Country': 'US',
#   'Date': 1569561315,
#   'Humidity': 87,
#   'Lat': 47.5,
#   'Lng': -111.29,
#   'Max Temp': 281.15,
#   'Wind Speed': 3.1},
#  {'City': 'Aklavik',
#   'Cloudiness': 75,
#   'Country': 'CA',
#   'Date': 1569561315,
#   'Humidity': 80,
#   'Lat': 68.22,
#   'Lng': -135.01,
#   'Max Temp': 275.15,
#   'Wind Speed': 1},
#  {'City': 'Constantine',
#   'Cloudiness': 0,
#   'Country': 'DZ',
#   'Date': 1569561315,
#   'Humidity': 93,
#   'Lat': 36.36,
#   'Lng': 6.61,
#   'Max Temp': 287.15,
#   'Wind Speed': 0.48},
#  {'City': 'Umm Kaddadah',
#   'Cloudiness': 100,
#   'Country': 'SD',
#   'Date': 1569561315,
#   'Humidity': 47,
#   'Lat': 13.6,
#   'Lng': 26.69,
#   'Max Temp': 299.892,
#   'Wind Speed': 1.6},
#  {'City': 'Castro',
#   'Cloudiness': 0,
#   'Country': 'CL',
#   'Date': 1569561316,
#   'Humidity': 81,
#   'Lat': -42.48,
#   'Lng': -73.76,
#   'Max Temp': 283.15,
#   'Wind Speed': 2.1},
#  {'City': 'Nishihara',
#   'Cloudiness': 75,
#   'Country': 'JP',
#   'Date': 1569561316,
#   'Humidity': 65,
#   'Lat': 35.74,
#   'Lng': 139.53,
#   'Max Temp': 303.15,
#   'Wind Speed': 1.5},
#  {'City': 'Benguela',
#   'Cloudiness': 83,
#   'Country': 'AO',
#   'Date': 1569561316,
#   'Humidity': 84,
#   'Lat': -12.58,
#   'Lng': 13.4,
#   'Max Temp': 295.532,
#   'Wind Speed': 1.65},
#  {'City': 'Itatskiy',
#   'Cloudiness': 46,
#   'Country': 'RU',
#   'Date': 1569561317,
#   'Humidity': 46,
#   'Lat': 56.07,
#   'Lng': 89.04,
#   'Max Temp': 282.132,
#   'Wind Speed': 2.2},
#  {'City': 'New Norfolk',
#   'Cloudiness': 75,
#   'Country': 'AU',
#   'Date': 1569561317,
#   'Humidity': 54,
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Max Temp': 288.15,
#   'Wind Speed': 4.6},
#  {'City': 'Hopatcong',
#   'Cloudiness': 0,
#   'Country': 'US',
#   'Date': 1569561317,
#   'Humidity': 100,
#   'Lat': 40.93,
#   'Lng': -74.66,
#   'Max Temp': 289.82,
#   'Wind Speed': 1.19},
#  {'City': 'Taksimo',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1569561317,
#   'Humidity': 72,
#   'Lat': 56.36,
#   'Lng': 114.84,
#   'Max Temp': 282.052,
#   'Wind Speed': 1.59},
#  {'City': 'Babol',
#   'Cloudiness': 75,
#   'Country': 'IR',
#   'Date': 1569561317,
#   'Humidity': 88,
#   'Lat': 36.55,
#   'Lng': 52.68,
#   'Max Temp': 295.15,
#   'Wind Speed': 2.88},
#  {'City': 'Qazvin',
#   'Cloudiness': 0,
#   'Country': 'IR',
#   'Date': 1569561050,
#   'Humidity': 28,
#   'Lat': 36.28,
#   'Lng': 50.01,
#   'Max Temp': 294.15,
#   'Wind Speed': 1},
#  {'City': 'Zilair',
#   'Cloudiness': 55,
#   'Country': 'RU',
#   'Date': 1569561318,
#   'Humidity': 77,
#   'Lat': 52.23,
#   'Lng': 57.44,
#   'Max Temp': 277.472,
#   'Wind Speed': 5.17},
#  {'City': 'Ust-Ilimsk',
#   'Cloudiness': 67,
#   'Country': 'RU',
#   'Date': 1569561318,
#   'Humidity': 77,
#   'Lat': 57.96,
#   'Lng': 102.73,
#   'Max Temp': 274.502,
#   'Wind Speed': 4.53},
#  {'City': 'Ugoofaaru',
#   'Cloudiness': 79,
#   'Country': 'MV',
#   'Date': 1569561318,
#   'Humidity': 63,
#   'Lat': 5.67,
#   'Lng': 73,
#   'Max Temp': 302.102,
#   'Wind Speed': 2.88},
#  {'City': 'Port Hardy',
#   'Cloudiness': 20,
#   'Country': 'CA',
#   'Date': 1569561318,
#   'Humidity': 81,
#   'Lat': 50.7,
#   'Lng': -127.42,
#   'Max Temp': 283.15,
#   'Wind Speed': 1.5},
#  {'City': 'Mahebourg',
#   'Cloudiness': 40,
#   'Country': 'MU',
#   'Date': 1569561319,
#   'Humidity': 73,
#   'Lat': -20.41,
#   'Lng': 57.7,
#   'Max Temp': 298.15,
#   'Wind Speed': 7.2},
#  {'City': 'Lewisporte',
#   'Cloudiness': 90,
#   'Country': 'CA',
#   'Date': 1569561319,
#   'Humidity': 100,
#   'Lat': 49.25,
#   'Lng': -55.06,
#   'Max Temp': 283.15,
#   'Wind Speed': 3.1},
#  {'City': 'Pitimbu',
#   'Cloudiness': 40,
#   'Country': 'BR',
#   'Date': 1569561319,
#   'Humidity': 94,
#   'Lat': -7.47,
#   'Lng': -34.81,
#   'Max Temp': 296.15,
#   'Wind Speed': 2.1},
#  {'City': 'Taicheng',
#   'Cloudiness': 0,
#   'Country': 'CN',
#   'Date': 1569561320,
#   'Humidity': 40,
#   'Lat': 22.25,
#   'Lng': 112.8,
#   'Max Temp': 304.82,
#   'Wind Speed': 2.93},
#  {'City': 'Yanam',
#   'Cloudiness': 75,
#   'Country': 'IN',
#   'Date': 1569561321,
#   'Humidity': 83,
#   'Lat': 16.73,
#   'Lng': 82.22,
#   'Max Temp': 301.15,
#   'Wind Speed': 1.5},
#  {'City': 'Mmabatho',
#   'Cloudiness': 0,
#   'Country': 'ZA',
#   'Date': 1569561321,
#   'Humidity': 31,
#   'Lat': -25.85,
#   'Lng': 25.61,
#   'Max Temp': 283.15,
#   'Wind Speed': 1},
#  {'City': 'Aksu',
#   'Cloudiness': 0,
#   'Country': 'KZ',
#   'Date': 1569561321,
#   'Humidity': 48,
#   'Lat': 52.04,
#   'Lng': 76.93,
#   'Max Temp': 283.15,
#   'Wind Speed': 4},
#  {'City': 'Rio Gallegos',
#   'Cloudiness': 0,
#   'Country': 'AR',
#   'Date': 1569561322,
#   'Humidity': 74,
#   'Lat': -51.62,
#   'Lng': -69.22,
#   'Max Temp': 274.15,
#   'Wind Speed': 1},
#  {'City': 'Waynesville',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1569561322,
#   'Humidity': 82,
# ...
#   'Cloudiness': 0,
#   'Country': 'UZ',
#   'Date': 1569561376,
#   'Humidity': 25,
#   'Lat': 40.56,
#   'Lng': 65.69,
#   'Max Temp': 302.15,
#   'Wind Speed': 5.1},
#  {'City': 'Soledade',
#   'Cloudiness': 75,
#   'Country': 'BR',
#   'Date': 1569561376,
#   'Humidity': 94,
#   'Lat': -7.06,
#   'Lng': -36.37,
#   'Max Temp': 293.15,
#   'Wind Speed': 2.1},
#  {'City': 'Guia de Isora',
#   'Cloudiness': 20,
#   'Country': 'ES',
#   'Date': 1569561376,
#   'Humidity': 73,
#   'Lat': 28.21,
#   'Lng': -16.78,
#   'Max Temp': 294.82,
#   'Wind Speed': 3.1},
#  {'City': 'Teguldet',
#   'Cloudiness': 65,
#   'Country': 'RU',
#   'Date': 1569561377,
#   'Humidity': 44,
#   'Lat': 57.31,
#   'Lng': 88.17,
#   'Max Temp': 281.312,
#   'Wind Speed': 3.19},
#  {'City': 'Purpe',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1569561377,
#   'Humidity': 90,
#   'Lat': 64.48,
#   'Lng': 76.69,
#   'Max Temp': 277.04,
#   'Wind Speed': 7.41},
#  {'City': 'Iwaki',
#   'Cloudiness': 20,
#   'Country': 'JP',
#   'Date': 1569561377,
#   'Humidity': 47,
#   'Lat': 37.05,
#   'Lng': 140.89,
#   'Max Temp': 300.93,
#   'Wind Speed': 1.5},
#  {'City': 'Kloulklubed',
#   'Cloudiness': 75,
#   'Country': 'PW',
#   'Date': 1569561300,
#   'Humidity': 70,
#   'Lat': 7.04,
#   'Lng': 134.26,
#   'Max Temp': 303.15,
#   'Wind Speed': 5.7},
#  {'City': 'Lagos',
#   'Cloudiness': 20,
#   'Country': 'NG',
#   'Date': 1569561003,
#   'Humidity': 94,
#   'Lat': 6.46,
#   'Lng': 3.39,
#   'Max Temp': 298.15,
#   'Wind Speed': 2.11},
#  {'City': 'Dunda',
#   'Cloudiness': 75,
#   'Country': 'IN',
#   'Date': 1569561378,
#   'Humidity': 88,
#   'Lat': 30.62,
#   'Lng': 78.32,
#   'Max Temp': 298.15,
#   'Wind Speed': 1.5},
#  {'City': 'Xiongzhou',
#   'Cloudiness': 20,
#   'Country': 'CN',
#   'Date': 1569561378,
#   'Humidity': 54,
#   'Lat': 32.34,
#   'Lng': 118.83,
#   'Max Temp': 305.37,
#   'Wind Speed': 3},
#  {'City': 'Pangnirtung',
#   'Cloudiness': 29,
#   'Country': 'CA',
#   'Date': 1569561378,
#   'Humidity': 32,
#   'Lat': 66.15,
#   'Lng': -65.72,
#   'Max Temp': 275.922,
#   'Wind Speed': 2.41},
#  {'City': 'Zhangye',
#   'Cloudiness': 0,
#   'Country': 'CN',
#   'Date': 1569561379,
#   'Humidity': 11,
#   'Lat': 38.94,
#   'Lng': 100.46,
#   'Max Temp': 296.422,
#   'Wind Speed': 3.57},
#  {'City': 'Kabare',
#   'Cloudiness': 93,
#   'Country': 'RW',
#   'Date': 1569561379,
#   'Humidity': 84,
#   'Lat': -1.65,
#   'Lng': 29.38,
#   'Max Temp': 290.092,
#   'Wind Speed': 0.83},
#  {'City': 'Te Anau',
#   'Cloudiness': 91,
#   'Country': 'NZ',
#   'Date': 1569561379,
#   'Humidity': 92,
#   'Lat': -45.41,
#   'Lng': 167.72,
#   'Max Temp': 279.112,
#   'Wind Speed': 4.56},
#  {'City': 'Luena',
#   'Cloudiness': 1,
#   'Country': 'AO',
#   'Date': 1569561379,
#   'Humidity': 58,
#   'Lat': -11.78,
#   'Lng': 19.91,
#   'Max Temp': 291.562,
#   'Wind Speed': 3.65},
#  {'City': 'Harper',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1569561380,
#   'Humidity': 53,
#   'Lat': 30.3,
#   'Lng': -99.24,
#   'Max Temp': 299.26,
#   'Wind Speed': 2.1},
#  {'City': 'Jining',
#   'Cloudiness': 0,
#   'Country': 'CN',
#   'Date': 1569561380,
#   'Humidity': 34,
#   'Lat': 35.41,
#   'Lng': 116.58,
#   'Max Temp': 303.142,
#   'Wind Speed': 1.48},
#  {'City': 'La Rioja',
#   'Cloudiness': 0,
#   'Country': 'AR',
#   'Date': 1569561380,
#   'Humidity': 45,
#   'Lat': -29.41,
#   'Lng': -66.86,
#   'Max Temp': 286.072,
#   'Wind Speed': 0.96},
#  {'City': 'Lubsko',
#   'Cloudiness': 97,
#   'Country': 'PL',
#   'Date': 1569561380,
#   'Humidity': 100,
#   'Lat': 51.79,
#   'Lng': 14.97,
#   'Max Temp': 288.71,
#   'Wind Speed': 3.78},
#  {'City': 'Cabo San Lucas',
#   'Cloudiness': 5,
#   'Country': 'MX',
#   'Date': 1569561261,
#   'Humidity': 83,
#   'Lat': 22.89,
#   'Lng': -109.91,
#   'Max Temp': 300.37,
#   'Wind Speed': 5.7},
#  {'City': 'Kibala',
#   'Cloudiness': 0,
#   'Country': 'TD',
#   'Date': 1569561381,
#   'Humidity': 94,
#   'Lat': 9.11,
#   'Lng': 18.35,
#   'Max Temp': 297.15,
#   'Wind Speed': 2.17},
#  {'City': 'Salalah',
#   'Cloudiness': 40,
#   'Country': 'OM',
#   'Date': 1569561381,
#   'Humidity': 74,
#   'Lat': 17.01,
#   'Lng': 54.1,
#   'Max Temp': 301.15,
#   'Wind Speed': 1},
#  {'City': 'Sieut',
#   'Cloudiness': 88,
#   'Country': 'RO',
#   'Date': 1569561381,
#   'Humidity': 87,
#   'Lat': 46.98,
#   'Lng': 24.65,
#   'Max Temp': 287.15,
#   'Wind Speed': 3.1},
#  {'City': 'El Carmen',
#   'Cloudiness': 0,
#   'Country': 'AR',
#   'Date': 1569561382,
#   'Humidity': 51,
#   'Lat': -24.39,
#   'Lng': -65.26,
#   'Max Temp': 293.15,
#   'Wind Speed': 1.89},
#  {'City': 'Zhigansk',
#   'Cloudiness': 79,
#   'Country': 'RU',
#   'Date': 1569561382,
#   'Humidity': 58,
#   'Lat': 66.77,
#   'Lng': 123.37,
#   'Max Temp': 277.372,
#   'Wind Speed': 0.66},
#  {'City': 'Vagamo',
#   'Cloudiness': 100,
#   'Country': 'NO',
#   'Date': 1569561382,
#   'Humidity': 98,
#   'Lat': 61.88,
#   'Lng': 9.1,
#   'Max Temp': 276.012,
#   'Wind Speed': 4.27},
#  {'City': 'Luganville',
#   'Cloudiness': 75,
#   'Country': 'VU',
#   'Date': 1569561382,
#   'Humidity': 69,
#   'Lat': -15.51,
#   'Lng': 167.18,
#   'Max Temp': 300.15,
#   'Wind Speed': 5.1},
#  {'City': 'Basoko',
#   'Cloudiness': 100,
#   'Country': 'CD',
#   'Date': 1569561382,
#   'Humidity': 94,
#   'Lat': 1.23,
#   'Lng': 23.61,
#   'Max Temp': 295.172,
#   'Wind Speed': 0.31},
#  {'City': 'Burgeo',
#   'Cloudiness': 55,
#   'Country': 'CA',
#   'Date': 1569561383,
#   'Humidity': 90,
#   'Lat': 47.61,
#   'Lng': -57.61,
#   'Max Temp': 284.772,
#   'Wind Speed': 4.3},
#  {'City': 'Chirongui',
#   'Cloudiness': 0,
#   'Country': 'YT',
#   'Date': 1569561383,
#   'Humidity': 69,
#   'Lat': -12.93,
#   'Lng': 45.15,
#   'Max Temp': 300.15,
#   'Wind Speed': 8.7},
#  {'City': 'Zlitan',
#   'Cloudiness': 3,
#   'Country': 'LY',
#   'Date': 1569561187,
#   'Humidity': 81,
#   'Lat': 32.47,
#   'Lng': 14.57,
#   'Max Temp': 296.902,
#   'Wind Speed': 3.04},
#  {'City': 'Altay',
#   'Cloudiness': 72,
#   'Country': 'CN',
#   'Date': 1569561383,
#   'Humidity': 39,
#   'Lat': 47.83,
#   'Lng': 88.13,
#   'Max Temp': 285.642,
#   'Wind Speed': 2.67},
#  {'City': 'Ussel',
#   'Cloudiness': 95,
#   'Country': 'FR',
#   'Date': 1569561383,
#   'Humidity': 94,
#   'Lat': 45.55,
#   'Lng': 2.31,
#   'Max Temp': 287.04,
#   'Wind Speed': 2.03},
#  {'City': 'Zhezkazgan',
#   'Cloudiness': 90,
#   'Country': 'KZ',
#   'Date': 1569561384,
#   'Humidity': 38,
#   'Lat': 47.8,
#   'Lng': 67.71,
#   'Max Temp': 289.15,
#   'Wind Speed': 3},
#  {'City': 'Whyalla',
#   'Cloudiness': 0,
#   'Country': 'AU',
#   'Date': 1569561134,
#   'Humidity': 67,
#   'Lat': -33.04,
#   'Lng': 137.58,
#   'Max Temp': 290.15,
#   'Wind Speed': 8.7},
#  {'City': 'Ballina',
#   'Cloudiness': 95,
#   'Country': 'IE',
#   'Date': 1569561384,
#   'Humidity': 95,
#   'Lat': 54.11,
#   'Lng': -9.15,
#   'Max Temp': 287.04,
#   'Wind Speed': 4.24},
#  {'City': 'Lata',
#   'Cloudiness': 28,
#   'Country': 'IN',
#   'Date': 1569561384,
#   'Humidity': 90,
#   'Lat': 30.78,
#   'Lng': 78.62,
#   'Max Temp': 281.092,
#   'Wind Speed': 3.05},
#  {'City': 'Kjollefjord',
#   'Cloudiness': 90,
#   'Country': 'NO',
#   'Date': 1569561384,
#   'Humidity': 100,
#   'Lat': 70.95,
#   'Lng': 27.35,
#   'Max Temp': 281.15,
#   'Wind Speed': 7.7},
#  {'City': 'Amapa',
#   'Cloudiness': 75,
#   'Country': 'HN',
#   'Date': 1569561385,
#   'Humidity': 83,
#   'Lat': 15.09,
#   'Lng': -87.97,
#   'Max Temp': 298.15,
#   'Wind Speed': 7.2},
#  {'City': 'Jardim',
#   'Cloudiness': 25,
#   'Country': 'BR',
#   'Date': 1569561385,
#   'Humidity': 68,
#   'Lat': -21.48,
#   'Lng': -56.15,
#   'Max Temp': 291.802,
#   'Wind Speed': 1.17},
#  {'City': 'Amga',
#   'Cloudiness': 79,
#   'Country': 'RU',
#   'Date': 1569561385,
#   'Humidity': 63,
#   'Lat': 60.89,
#   'Lng': 131.98,
#   'Max Temp': 280.922,
#   'Wind Speed': 2.67},
#  {'City': 'Puro',
#   'Cloudiness': 36,
#   'Country': 'PH',
#   'Date': 1569561385,
#   'Humidity': 71,
#   'Lat': 13.13,
#   'Lng': 123.76,
#   'Max Temp': 302.712,
#   'Wind Speed': 3.32},
#  {'City': 'Lengshuitan',
#   'Cloudiness': 12,
#   'Country': 'CN',
#   'Date': 1569561386,
#   'Humidity': 25,
#   'Lat': 26.41,
#   'Lng': 111.6,
#   'Max Temp': 305.292,
#   'Wind Speed': 3.45},
#  {'City': 'Pak Phanang',
#   'Cloudiness': 20,
#   'Country': 'TH',
#   'Date': 1569561386,
#   'Humidity': 70,
#   'Lat': 8.35,
#   'Lng': 100.2,
#   'Max Temp': 304.15,
#   'Wind Speed': 3.6},
#  {'City': 'Mikuni',
#   'Cloudiness': 40,
#   'Country': 'JP',
#   'Date': 1569561386,
#   'Humidity': 51,
#   'Lat': 36.22,
#   'Lng': 136.15,
#   'Max Temp': 302.15,
#   'Wind Speed': 5.7},
#  {'City': 'Antofagasta',
#   'Cloudiness': 90,
#   'Country': 'CL',
#   'Date': 1569561279,
#   'Humidity': 71,
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 287.15,
#   'Wind Speed': 2.1},
#  {'City': 'Port Shepstone',
#   'Cloudiness': 0,
#   'Country': 'ZA',
#   'Date': 1569561386,
#   'Humidity': 29,
#   'Lat': -30.74,
#   'Lng': 30.45,
#   'Max Temp': 292.632,
#   'Wind Speed': 1.71},
#  {'City': 'Coahuayana',
#   'Cloudiness': 100,
#   'Country': 'MX',
#   'Date': 1569561387,
#   'Humidity': 93,
#   'Lat': 18.62,
#   'Lng': -100.35,
#   'Max Temp': 296.252,
#   'Wind Speed': 2.05},
#  {'City': 'Port Blair',
#   'Cloudiness': 72,
#   'Country': 'IN',
#   'Date': 1569561387,
#   'Humidity': 72,
#   'Lat': 11.67,
#   'Lng': 92.75,
#   'Max Temp': 302.022,
#   'Wind Speed': 2.64},
#  {'City': 'Sabha',
#   'Cloudiness': 0,
#   'Country': 'LY',
#   'Date': 1569561387,
#   'Humidity': 39,
#   'Lat': 27.03,
#   'Lng': 14.43,
#   'Max Temp': 298.322,
#   'Wind Speed': 4},
#  {'City': 'Srednekolymsk',
#   'Cloudiness': 78,
#   'Country': 'RU',
#   'Date': 1569561387,
#   'Humidity': 54,
#   'Lat': 67.46,
#   'Lng': 153.71,
#   'Max Temp': 275.002,
#   'Wind Speed': 1.79},
#  {'City': 'Buala',
#   'Cloudiness': 18,
#   'Country': 'SB',
#   'Date': 1569561388,
#   'Humidity': 69,
#   'Lat': -8.15,
#   'Lng': 159.59,
#   'Max Temp': 301.572,
#   'Wind Speed': 2.02},
#  {'City': 'Esmeralda',
#   'Cloudiness': 76,
#   'Country': 'CL',
#   'Date': 1569561388,
#   'Humidity': 97,
#   'Lat': -34.33,
#   'Lng': -70.9,
#   'Max Temp': 283.122,
#   'Wind Speed': 2.22},
#  {'City': 'Anchorage',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1569561388,
#   'Humidity': 93,
#   'Lat': 61.22,
#   'Lng': -149.89,
#   'Max Temp': 280.15,
#   'Wind Speed': 2.1},
#  {'City': 'Issoudun',
#   'Cloudiness': 100,
#   'Country': 'FR',
#   'Date': 1569561388,
#   'Humidity': 87,
#   'Lat': 46.95,
#   'Lng': 1.99,
#   'Max Temp': 289.26,
#   'Wind Speed': 8.2},
#  {'City': 'Samarai',
#   'Cloudiness': 86,
#   'Country': 'PG',
#   'Date': 1569561389,
#   'Humidity': 88,
#   'Lat': -10.62,
#   'Lng': 150.67,
#   'Max Temp': 298.542,
#   'Wind Speed': 3.51},
#  {'City': 'Pingliang',
#   'Cloudiness': 0,
#   'Country': 'CN',
#   'Date': 1569561389,
#   'Humidity': 37,
#   'Lat': 35.54,
#   'Lng': 106.68,
#   'Max Temp': 293.282,
#   'Wind Speed': 2.59},
#  {'City': 'North Platte',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1569561341,
#   'Humidity': 68,
#   'Lat': 41.12,
#   'Lng': -100.77,
#   'Max Temp': 292.15,
#   'Wind Speed': 2.6},
#  {'City': 'Erzin',
#   'Cloudiness': 0,
#   'Country': 'TR',
#   'Date': 1569561389,
#   'Humidity': 94,
#   'Lat': 36.95,
#   'Lng': 36.2,
#   'Max Temp': 297.04,
#   'Wind Speed': 0.21},
#  {'City': 'Colares',
#   'Cloudiness': 20,
#   'Country': 'PT',
#   'Date': 1569561389,
#   'Humidity': 87,
#   'Lat': 38.8,
#   'Lng': -9.45,
#   'Max Temp': 290.93,
#   'Wind Speed': 1.5},
#  {'City': 'Koraput',
#   'Cloudiness': 99,
#   'Country': 'IN',
#   'Date': 1569561390,
#   'Humidity': 60,
#   'Lat': 18.81,
#   'Lng': 82.72,
#   'Max Temp': 301.542,
#   'Wind Speed': 2.96},
#  {'City': 'Tarko-Sale',
#   'Cloudiness': 98,
#   'Country': 'RU',
#   'Date': 1569561390,
#   'Humidity': 90,
#   'Lat': 64.92,
#   'Lng': 77.78,
#   'Max Temp': 277.04,
#   'Wind Speed': 7.3},
#  {'City': 'Bafq',
#   'Cloudiness': 0,
#   'Country': 'IR',
#   'Date': 1569561390,
#   'Humidity': 6,
#   'Lat': 31.6,
#   'Lng': 55.4,
#   'Max Temp': 302.892,
#   'Wind Speed': 2.47},
#  {'City': 'Oistins',
#   'Cloudiness': 20,
#   'Country': 'BB',
#   'Date': 1569561391,
#   'Humidity': 78,
#   'Lat': 13.07,
#   'Lng': -59.53,
#   'Max Temp': 300.15,
#   'Wind Speed': 4.1},
#  {'City': 'Nizhnevartovsk',
#   'Cloudiness': 0,
#   'Country': 'RU',
#   'Date': 1569561391,
#   'Humidity': 80,
#   'Lat': 60.93,
#   'Lng': 76.58,
#   'Max Temp': 277.15,
#   'Wind Speed': 4},
#  {'City': 'Tefe',
#   'Cloudiness': 2,
#   'Country': 'BR',
#   'Date': 1569561391,
#   'Humidity': 87,
#   'Lat': -3.35,
#   'Lng': -64.71,
#   'Max Temp': 296.492,
#   'Wind Speed': 1.22},
#  {'City': 'College',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': 1569561392,
#   'Humidity': 93,
#   'Lat': 64.86,
#   'Lng': -147.8,
#   'Max Temp': 277.15,
#   'Wind Speed': 1.29},
#  {'City': 'Muroto',
#   'Cloudiness': 75,
#   'Country': 'JP',
#   'Date': 1569561392,
#   'Humidity': 88,
#   'Lat': 33.37,
#   'Lng': 134.14,
#   'Max Temp': 297.15,
#   'Wind Speed': 2.1},
#  {'City': 'Kontagora',
#   'Cloudiness': 99,
#   'Country': 'NG',
#   'Date': 1569561392,
#   'Humidity': 94,
#   'Lat': 10.4,
#   'Lng': 5.47,
#   'Max Temp': 296.392,
#   'Wind Speed': 2.1},
#  {'City': 'Teya',
#   'Cloudiness': 90,
#   'Country': 'MX',
#   'Date': 1569561393,
#   'Humidity': 94,
#   'Lat': 21.05,
#   'Lng': -89.07,
#   'Max Temp': 300.93,
#   'Wind Speed': 3.1},
#  {'City': 'Mandera',
#   'Cloudiness': 100,
#   'Country': 'ET',
#   'Date': 1569561393,
#   'Humidity': 60,
#   'Lat': 3.94,
#   'Lng': 41.86,
#   'Max Temp': 301.48,
#   'Wind Speed': 2.68},
#  {'City': 'Gabaldon',
#   'Cloudiness': 1,
#   'Country': 'PH',
#   'Date': 1569561393,
#   'Humidity': 65,
#   'Lat': 15.45,
#   'Lng': 121.34,
#   'Max Temp': 304.732,
#   'Wind Speed': 1.4},
#  {'City': 'Morehead',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1569561393,
#   'Humidity': 82,
#   'Lat': 38.18,
#   'Lng': -83.43,
#   'Max Temp': 288.15,
#   'Wind Speed': 1.75},
#  {'City': 'Mecca',
#   'Cloudiness': 0,
#   'Country': 'SA',
#   'Date': 1569561393,
#   'Humidity': 12,
#   'Lat': 21.43,
#   'Lng': 39.83,
#   'Max Temp': 312.872,
#   'Wind Speed': 3.6},
#  {'City': 'Carballo',
#   'Cloudiness': 75,
#   'Country': 'ES',
#   'Date': 1569561394,
#   'Humidity': 100,
#   'Lat': 43.21,
#   'Lng': -8.69,
#   'Max Temp': 291.48,
#   'Wind Speed': 1},
#  {'City': 'Sibiti',
#   'Cloudiness': 100,
#   'Country': 'CG',
#   'Date': 1569561394,
#   'Humidity': 89,
#   'Lat': -3.69,
#   'Lng': 13.35,
#   'Max Temp': 295.712,
#   'Wind Speed': 0.34},
#  {'City': 'Bulgan',
#   'Cloudiness': 59,
#   'Country': 'MN',
#   'Date': 1569561394,
#   'Humidity': 50,
#   'Lat': 48.81,
#   'Lng': 103.53,
#   'Max Temp': 288.232,
#   'Wind Speed': 4.68},
#  {'City': 'Launceston',
#   'Cloudiness': 90,
#   'Country': 'AU',
#   'Date': 1569561394,
#   'Humidity': 93,
#   'Lat': -41.43,
#   'Lng': 147.14,
#   'Max Temp': 284.26,
#   'Wind Speed': 7.7},
#  {'City': 'Amazar',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': 1569561395,
#   'Humidity': 79,
#   'Lat': 53.86,
#   'Lng': 120.88,
#   'Max Temp': 286.422,
#   'Wind Speed': 1.18},
#  {'City': 'Antalaha',
#   'Cloudiness': 84,
#   'Country': 'MG',
#   'Date': 1569561395,
#   'Humidity': 59,
#   'Lat': -14.9,
#   'Lng': 50.28,
#   'Max Temp': 297.782,
#   'Wind Speed': 1.1},
#  {'City': 'Yuyao',
#   'Cloudiness': 40,
#   'Country': 'CN',
#   'Date': 1569561138,
#   'Humidity': 51,
#   'Lat': 30.04,
#   'Lng': 121.15,
#   'Max Temp': 300.37,
#   'Wind Speed': 2},
#  {'City': 'Galveston',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1569561395,
#   'Humidity': 87,
#   'Lat': 40.58,
#   'Lng': -86.19,
#   'Max Temp': 285.93,
#   'Wind Speed': 2.6},
#  {'City': 'Biak',
#   'Cloudiness': 100,
#   'Country': 'ID',
#   'Date': 1569561395,
#   'Humidity': 93,
#   'Lat': -0.91,
#   'Lng': 122.88,
#   'Max Temp': 293.772,
#   'Wind Speed': 1.23},
#  {'City': 'Sechura',
#   'Cloudiness': 5,
#   'Country': 'PE',
#   'Date': 1569561396,
#   'Humidity': 90,
#   'Lat': -5.56,
#   'Lng': -80.82,
#   'Max Temp': 289.912,
#   'Wind Speed': 2.93},
#  {'City': 'Tshikapa',
#   'Cloudiness': 17,
#   'Country': 'CD',
#   'Date': 1569561396,
#   'Humidity': 79,
#   'Lat': -6.42,
#   'Lng': 20.79,
#   'Max Temp': 295.642,
#   'Wind Speed': 0.22},
#  {'City': 'Kushima',
#   'Cloudiness': 75,
#   'Country': 'JP',
#   'Date': 1569561396,
#   'Humidity': 83,
#   'Lat': 31.5,
#   'Lng': 131.29,
#   'Max Temp': 301.15,
#   'Wind Speed': 5.7},
#  {'City': 'Codrington',
#   'Cloudiness': 75,
#   'Country': 'AU',
#   'Date': 1569561396,
#   'Humidity': 37,
#   'Lat': -28.95,
#   'Lng': 153.24,
#   'Max Temp': 301.15,
#   'Wind Speed': 5.7},
#  {'City': 'Agua Dulce',
#   'Cloudiness': 100,
#   'Country': 'MX',
#   'Date': 1569561397,
#   'Humidity': 94,
#   'Lat': 18.14,
#   'Lng': -94.15,
#   'Max Temp': 297.662,
#   'Wind Speed': 1.18},
#  {'City': 'Lazaro Cardenas',
#   'Cloudiness': 40,
#   'Country': 'MX',
#   'Date': 1569561398,
#   'Humidity': 68,
#   'Lat': 28.39,
#   'Lng': -105.62,
#   'Max Temp': 295.15,
#   'Wind Speed': 3.1},
#  {'City': 'Ironton',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': 1569561398,
#   'Humidity': 82,
#   'Lat': 38.54,
#   'Lng': -82.68,
#   'Max Temp': 289.82,
#   'Wind Speed': 1.5}]

# %%
# Convert to dataframe
weather_data_df = pd.DataFrame(city_weather_list)

# Check if directory exists
os.makedirs(output_directory, exist_ok=True)

# Save to Csv
weather_data_df.to_csv(os.path.join(output_directory, output_data_file), index=False, header=True)

# Preview Dataframe counts
weather_data_df.count()
# Out:
# City          551
# Cloudiness    551
# Country       551
# Date          551
# Humidity      551
# Lat           551
# Lng           551
# Max Temp      551
# Wind Speed    551
# dtype: int64

# %%
# def _json_object_hook(d): return namedtuple('x', d.keys())(*d.values())
# def json2obj(data): return json.loads(data, object_hook=_json_object_hook)

# data = cities_weather_data[0]

# x = json2obj(json.dumps(data))

# pp(x)
# pp(x.weather[0].main)
# pp(x.coord.lon)

# pp(f'{x.name}, {x.clouds.all}, {x.sys.country}, {x.dt}, {x.main.humidity}, {x.coord.lat}, {x.coord.lon}, {x.main.temp_max}, {x.wind.speed}')

# dict = {
#     'City': x.name,
#     'Cloudiness' : x.clouds.all,
#     'Country': x.sys.country,
#     'Date': x.dt,
#     'Humidity': x.main.humidity,
#     'Lat': x.coord.lat,
#     'Lng': x.coord.lon,
#     'Max Temp': x.main.temp_max,
#     'Wind Speed': x.wind.speed
# }

# df = pd.DataFrame([dict])
# df

# %%
# Preview Dataframe
weather_data_df.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      Turayf           0      SA  1569561251        34  31.68   38.65
# 1       Tupik         100      RU  1569561252        91  54.43  119.94
# 2     Kavieng          65      PG  1569561252        73  -2.57  150.80
# 3  North Bend          75      US  1569561252        82  43.41 -124.22
# 4     Youghal          75      IE  1569561252        93  51.95   -7.85
#
#    Max Temp  Wind Speed
# 0   291.150        3.10
# 1   283.482        1.31
# 2   302.222        4.92
# 3   288.710        3.10
# 4   287.590        8.20

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data_df['Lat'],weather_data_df['Max Temp'],marker="o", facecolors="green", edgecolors="black",alpha=0.75)
plt.grid()
plt.title('City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Tempature (F)')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data_df['Lat'],weather_data_df['Humidity'],marker="o", facecolors="green", edgecolors="black",alpha=0.75)
plt.grid()
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.ylim(-5, 109)
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data_df['Lat'],weather_data_df['Cloudiness'],marker="o", facecolors="green", edgecolors="black",alpha=0.75)
plt.grid()
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.ylim(-5, 108)
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data_df['Lat'],weather_data_df['Wind Speed'],marker="o", facecolors="green", edgecolors="black",alpha=0.75)
plt.grid()
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(mph)')
plt.show()
